# %% [markdown]
# # Storing Fantasy Premier League data in a database - part 1
# - Author: Steffan Rees
# - 17/04/2022

# %% [markdown]
# ## Background
# In this series of notebooks we will cover the following:
# - Extracting data from an API (part 1)
# - Transforming the data (part 1)
# - Storing the data in a database (part 1)
# - Querying the database (part 2)
# - Comparing SQL to pandas (part 2)

# %% [markdown]
# ### How do extract data from https://fantasy.premierleague.com?
# Before jumping to using a web scraping library, we can check whether an API exists. Luckily for us one does exist which makes the tasks a lot easier. However, how do we find out that an API exists in the first place? To check whether an API is being used to populate data on a website, we can investigate the network of a given web page. For example on https://fantasy.premierleague.com/statistics, we see a GET request being made to https://fantasy.premierleague.com/api/bootstrap-static/ which contains some data we can extract!
#
# Once we have found the API call, we can use software such as Postman to retrieve the code needed to make the API call. Postman also allows easier viewing of the structure of the data.
#
# To save time finding all the individual end points, we can reference the excellent Medium post https://medium.com/@frenzelts/fantasy-premier-league-api-endpoints-a-detailed-guide-acbd5598eb19.
#
# In this notebook we will focus on the constant end points - the variable end points will be left as an exercise.

# %%
# Import libraries
import requests
import pandas as pd
import sqlite3

# %%
# Connect to the database
def sql_connection(db):
    try:
        con = sqlite3.connect(db)
    except Error:
        print(Error)
        
    cursor = con.cursor()
    return con, cursor

# %%
# Drop table if it exists
def drop_table_if_exists(cur, con, table):
    query = f'DROP TABLE IF EXISTS {table}'
    cur.execute(query)
    con.commit()

# %%
# Constant end points
BOOTSRAP_STATIC_URL = "https://fantasy.premierleague.com/api/bootstrap-static/"
FIXTURES_URL = "https://fantasy.premierleague.com/api/fixtures/"
EVENT_STATUS_URL = "https://fantasy.premierleague.com/api/event-status/"
SET_PIECE_URL = "https://fantasy.premierleague.com/api/team/set-piece-notes/"

# %% [markdown]
# #### Variable end points
# - https://fantasy.premierleague.com/api/element-summary/{element_id}/
# - https://fantasy.premierleague.com/api/event/{event_id}/live/
# - https://fantasy.premierleague.com/api/entry/{manager_id}/
# - https://fantasy.premierleague.com/api/entry/{manager_id}/history/
# - https://fantasy.premierleague.com/api/entry/{manager_id}/event/{gameweek}/picks/'
# - https://fantasy.premierleague.com/api/leagues-classic/{league_id}/standings
# - https://fantasy.premierleague.com/api/dream-team/{event_id}/

# %% [markdown]
# ## General information

# %%
# Extract the information available in the bootstrap-static end point
def get_bootstrap_static(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"Request failed. Return code is {response.status_code}.")

# %%
bootstrap_static = get_bootstrap_static(BOOTSRAP_STATIC_URL)

# %%
# What subsets of data exist?
bootstrap_static.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %% [markdown]
# ### Events
# Basic information of every gameweek such as average score, highest score, top scoring player, most captained, etc.

# %%
# First gameweek
bootstrap_static['events'][0]
# Out:
# {'id': 1,
#  'name': 'Gameweek 1',
#  'deadline_time': '2021-08-13T17:30:00Z',
#  'average_entry_score': 69,
#  'finished': True,
#  'data_checked': True,
#  'highest_scoring_entry': 5059647,
#  'deadline_time_epoch': 1628875800,
#  'deadline_time_game_offset': 0,
#  'highest_score': 150,
#  'is_previous': False,
#  'is_current': False,
#  'is_next': False,
#  'cup_leagues_created': False,
#  'h2h_ko_matches_created': False,
#  'chip_plays': [{'chip_name': 'bboost', 'num_played': 145658},
#   {'chip_name': '3xc', 'num_played': 225749}],
#  'most_selected': 275,
#  'most_transferred_in': 1,
#  'top_element': 277,
#  'top_element_info': {'id': 277, 'points': 20},
#  'transfers_made': 0,
#  'most_captained': 233,
#  'most_vice_captained': 277}

# %%
# Last gameweek
bootstrap_static['events'][-1]
# Out:
# {'id': 38,
#  'name': 'Gameweek 38',
#  'deadline_time': '2022-05-22T12:30:00Z',
#  'average_entry_score': 0,
#  'finished': False,
#  'data_checked': False,
#  'highest_scoring_entry': None,
#  'deadline_time_epoch': 1653222600,
#  'deadline_time_game_offset': 0,
#  'highest_score': None,
#  'is_previous': False,
#  'is_current': False,
#  'is_next': False,
#  'cup_leagues_created': False,
#  'h2h_ko_matches_created': False,
#  'chip_plays': [],
#  'most_selected': None,
#  'most_transferred_in': None,
#  'top_element': None,
#  'top_element_info': None,
#  'transfers_made': 0,
#  'most_captained': None,
#  'most_vice_captained': None}

# %%
# Extract the current gameweek
def get_current_gameweek():
    bootstrap_static = get_bootstrap_static(BOOTSRAP_STATIC_URL)
    events = bootstrap_static['events']
    for index in range(len(events)):
        for key in events[index]:
            if key == 'finished' and events[index][key] == False:
                gameweek = events[index]['id']
                break
        else:
            continue
        return gameweek

# %%
# Current gameweek
current_gameweek = get_current_gameweek()
bootstrap_static['events'][current_gameweek-1]
# Out:
# {'id': 35,
#  'name': 'Gameweek 35',
#  'deadline_time': '2022-04-30T10:00:00Z',
#  'average_entry_score': 33,
#  'finished': False,
#  'data_checked': False,
#  'highest_scoring_entry': 425643,
#  'deadline_time_epoch': 1651312800,
#  'deadline_time_game_offset': 0,
#  'highest_score': 113,
#  'is_previous': False,
#  'is_current': True,
#  'is_next': False,
#  'cup_leagues_created': True,
#  'h2h_ko_matches_created': True,
#  'chip_plays': [{'chip_name': 'bboost', 'num_played': 66736},
#   {'chip_name': 'freehit', 'num_played': 36325},
#   {'chip_name': 'wildcard', 'num_played': 127267},
#   {'chip_name': '3xc', 'num_played': 37782}],
#  'most_selected': 233,
#  'most_transferred_in': 263,
#  'top_element': 359,
#  'top_element_info': {'id': 359, 'points': 16},
#  'transfers_made': 6143352,
#  'most_captained': 233,
#  'most_vice_captained': 233}

# %%
# Extract wildcard information
def extract_wildcard_info(chips, chip_type):
    for index in range(len(chips)):
        for key in chips[index]:
            if chips[index][key] == chip_type:
                num_played = chips[index]['num_played']
                break
        else:
            continue
        return num_played

# %%
# Store events data in a dataframe
def events_table():
    bootstrap_static = get_bootstrap_static(BOOTSRAP_STATIC_URL)
    events_df = pd.DataFrame(bootstrap_static['events'])
    return (events_df
            .assign(most_points_score = events_df.top_element_info.apply(lambda x: None if x is None else x['points']),
                    bboost_played = events_df.chip_plays.apply(lambda x: None if not x else extract_wildcard_info(x, 'bboost')),
                    freehit_played = events_df.chip_plays.apply(lambda x: None if not x else extract_wildcard_info(x, 'freehit')),
                    wildcard_played = events_df.chip_plays.apply(lambda x: None if not x else extract_wildcard_info(x, 'wildcard')),
                    triple_captain_played = events_df.chip_plays.apply(lambda x: None if not x else extract_wildcard_info(x, '3xc')),
                   )
            .astype({'id': 'int8',
                     'average_entry_score': 'int8',
                     'highest_scoring_entry': 'Int32',
                     'deadline_time_game_offset': 'int8',
                     'highest_score': 'Int32',
                     'most_selected': 'Int32',
                     'most_transferred_in': 'Int32',
                     'top_element': 'Int32',
                     'transfers_made': 'int32',
                     'most_captained': 'Int32',
                     'most_vice_captained': 'Int32',
                     'most_points_score': 'Int8',
                     'bboost_played': 'Int32',
                     'freehit_played': 'Int32',
                     'wildcard_played': 'Int32',
                     'triple_captain_played': 'Int32'
                    })
            .drop(columns=['top_element_info', 'chip_plays'])
            .rename(columns={'id': 'gameweek_id',
                             'name': 'gameweek_name',
                             'most_selected': 'most_selected_id',
                             'most_transferred_in': 'most_transferred_in_id',
                             'top_element': 'top_player_id',
                             'highest_scoring_entry': 'highest_scoring_entry_id',
                             'most_captained': 'most_captained_id',
                             'most_vice_captained': 'most_vice_captained_id'
                            })
           )

# %%
events = events_table()
print(events.shape)
events.head()
# Out:
# (38, 26)
#    gameweek_id gameweek_name         deadline_time  average_entry_score  \
# 0            1    Gameweek 1  2021-08-13T17:30:00Z                   69
# 1            2    Gameweek 2  2021-08-21T10:00:00Z                   56
# 2            3    Gameweek 3  2021-08-28T10:00:00Z                   54
# 3            4    Gameweek 4  2021-09-11T10:00:00Z                   57
# 4            5    Gameweek 5  2021-09-17T17:30:00Z                   55
#
#    finished  data_checked  highest_scoring_entry_id  deadline_time_epoch  \
# 0      True          True                   5059647           1628875800
# 1      True          True                   6882931           1629540000
# 2      True          True                   7516002           1630144800
# 3      True          True                   7797969           1631354400
# 4      True          True                   3139954           1631899800
#
#    deadline_time_game_offset  highest_score  ...  most_transferred_in_id  \
# 0                          0            150  ...                       1
# 1                          0            146  ...                     272
# 2                          0            119  ...                     419
# 3                          0            120  ...                     579
# 4                          0            144  ...                     579
#
#    top_player_id  transfers_made  most_captained_id  most_vice_captained_id  \
# 0            277               0                233                     277
# 1            142        12038724                233                     277
# 2            268        15553648                277                     277
# 3            432        28985870                233                     233
# 4             44        18706283                233                     579
#
#    most_points_score  bboost_played  freehit_played  wildcard_played  \
# 0                 20         145658            <NA>             <NA>
# 1                 18          95038          102410           277209
# 2                 18          94049          117627           372083
# 3                 13          77204          168976          1117718
# 4                 15          49533          127510           708431
#
#    triple_captain_played
# 0                 225749
# 1                 269514
# 2                 138714
# 3                 157121
# 4                 104192
#
# [5 rows x 26 columns]

# %%
events.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   gameweek_id                38 non-null     int8
#  1   gameweek_name              38 non-null     object
#  2   deadline_time              38 non-null     object
#  3   average_entry_score        38 non-null     int8
#  4   finished                   38 non-null     bool
#  5   data_checked               38 non-null     bool
#  6   highest_scoring_entry_id   35 non-null     Int32
#  7   deadline_time_epoch        38 non-null     int64
#  8   deadline_time_game_offset  38 non-null     int8
#  9   highest_score              35 non-null     Int32
#  10  is_previous                38 non-null     bool
#  11  is_current                 38 non-null     bool
#  12  is_next                    38 non-null     bool
#  13  cup_leagues_created        38 non-null     bool
#  14  h2h_ko_matches_created     38 non-null     bool
#  15  most_selected_id           35 non-null     Int32
#  16  most_transferred_in_id     35 non-null     Int32
#  17  top_player_id              35 non-null     Int32
#  18  transfers_made             38 non-null     int32
#  19  most_captained_id          35 non-null     Int32
#  20  most_vice_captained_id     35 non-null     Int32
#  21  most_points_score          35 non-null     Int8
#  22  bboost_played              35 non-null     Int32
#  23  freehit_played             34 non-null     Int32
#  24  wildcard_played            34 non-null     Int32
#  25  triple_captain_played      35 non-null     Int32
# dtypes: Int32(11), Int8(1), bool(7), int32(1), int64(1), int8(3), object(2)
# memory usage: 3.7+ KB

# %%
# Load dataframe into a SQLite db table
con, cursor = sql_connection('fpl.db')
drop_table_if_exists(cursor, con, 'gameweeks')
events.to_sql(name='gameweeks', con=con, if_exists='replace', index=False, dtype={'gameweek_id': 'INTEGER PRIMARY KEY'})
con.commit()
con.close()

# %% [markdown]
# ### Teams
# Basic information of current Premier League clubs.

# %%
bootstrap_static['teams'][0]
# Out:
# {'code': 3,
#  'draw': 0,
#  'form': None,
#  'id': 1,
#  'loss': 0,
#  'name': 'Arsenal',
#  'played': 0,
#  'points': 0,
#  'position': 0,
#  'short_name': 'ARS',
#  'strength': 4,
#  'team_division': None,
#  'unavailable': False,
#  'win': 0,
#  'strength_overall_home': 1250,
#  'strength_overall_away': 1270,
#  'strength_attack_home': 1150,
#  'strength_attack_away': 1210,
#  'strength_defence_home': 1190,
#  'strength_defence_away': 1220,
#  'pulse_id': 1}

# %%
# Store teams data in a dataframe
def teams_table():
    bootstrap_static = get_bootstrap_static(BOOTSRAP_STATIC_URL)
    teams_df = pd.DataFrame(bootstrap_static['teams'])
    teams_df = (teams_df
                .astype({'code': 'int8',
                         'draw': 'int8',
                         'loss': 'int8',
                         'played': 'int8',
                         'points': 'int8',
                         'position': 'int8',
                         'strength': 'int8',
                         'win': 'int8',
                         'strength_overall_home': 'int16',
                         'strength_overall_away': 'int16',
                         'strength_attack_home': 'int16',
                         'strength_attack_away': 'int16',
                         'strength_defence_home': 'int16',
                         'strength_defence_away': 'int16',
                         'pulse_id': 'int16'
                        })
                .rename(columns={'code': 'team_code',
                                 'id': 'team_id',
                                 'name': 'team_name'
                                })
               )
    cols_to_move = ['team_id', 'team_code', 'team_name', 'short_name']
    teams_df = teams_df[cols_to_move + [ col for col in teams_df.columns if col not in cols_to_move ]]
    return teams_df

# %%
teams = teams_table()
print(teams.shape)
teams.head()
# Out:
# (20, 21)
#    team_id  team_code    team_name short_name  draw  form  loss  played  \
# 0        1          3      Arsenal        ARS     0  None     0       0
# 1        2          7  Aston Villa        AVL     0  None     0       0
# 2        3         94    Brentford        BRE     0  None     0       0
# 3        4         36     Brighton        BHA     0  None     0       0
# 4        5         90      Burnley        BUR     0  None     0       0
#
#    points  position  ...  team_division unavailable  win  \
# 0       0         0  ...           None       False    0
# 1       0         0  ...           None       False    0
# 2       0         0  ...           None       False    0
# 3       0         0  ...           None       False    0
# 4       0         0  ...           None       False    0
#
#    strength_overall_home  strength_overall_away  strength_attack_home  \
# 0                   1250                   1270                  1150
# 1                   1100                   1100                  1140
# 2                   1060                   1070                  1120
# 3                   1100                   1090                  1160
# 4                   1060                   1060                  1080
#
#    strength_attack_away  strength_defence_home  strength_defence_away  \
# 0                  1210                   1190                   1220
# 1                  1110                   1090                   1090
# 2                  1150                   1080                   1120
# 3                  1160                   1100                   1120
# 4                  1130                   1060                   1100
#
#    pulse_id
# 0         1
# 1         2
# 2       130
# 3       131
# 4        43
#
# [5 rows x 21 columns]

# %%
teams.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   team_id                20 non-null     int64
#  1   team_code              20 non-null     int8
#  2   team_name              20 non-null     object
#  3   short_name             20 non-null     object
#  4   draw                   20 non-null     int8
#  5   form                   0 non-null      object
#  6   loss                   20 non-null     int8
#  7   played                 20 non-null     int8
#  8   points                 20 non-null     int8
#  9   position               20 non-null     int8
#  10  strength               20 non-null     int8
#  11  team_division          0 non-null      object
#  12  unavailable            20 non-null     bool
#  13  win                    20 non-null     int8
#  14  strength_overall_home  20 non-null     int16
#  15  strength_overall_away  20 non-null     int16
#  16  strength_attack_home   20 non-null     int16
#  17  strength_attack_away   20 non-null     int16
#  18  strength_defence_home  20 non-null     int16
#  19  strength_defence_away  20 non-null     int16
#  20  pulse_id               20 non-null     int16
# dtypes: bool(1), int16(7), int64(1), int8(8), object(4)
# memory usage: 1.4+ KB

# %%
con, cursor = sql_connection('fpl.db')
drop_table_if_exists(cursor, con, 'teams')
teams.to_sql(name='teams', con=con, if_exists='replace', index=False, dtype={'team_id': 'INTEGER PRIMARY KEY'})
con.commit()
con.close()

# %% [markdown]
# ### Element type (player position)

# %%
bootstrap_static['element_types'][0]
# Out:
# {'id': 1,
#  'plural_name': 'Goalkeepers',
#  'plural_name_short': 'GKP',
#  'singular_name': 'Goalkeeper',
#  'singular_name_short': 'GKP',
#  'squad_select': 2,
#  'squad_min_play': 1,
#  'squad_max_play': 1,
#  'ui_shirt_specific': True,
#  'sub_positions_locked': [12],
#  'element_count': 83}

# %%
def position_table():
    bootstrap_static = get_bootstrap_static(BOOTSRAP_STATIC_URL)
    positions_df = pd.DataFrame(bootstrap_static['element_types'])
    return (positions_df
            .assign(sub_positions_locked = positions_df.sub_positions_locked.apply(lambda x: None if x == [] else int(''.join([str(i) for i in x]))))
            .astype({'id': 'int8',
                     'squad_select': 'int8',
                     'squad_min_play': 'int8',
                     'squad_max_play': 'int8',
                     'sub_positions_locked': 'Int8',
                     'element_count': 'int16'
                    })
            .rename(columns={'id': 'position_id'})
           )

# %%
positions = position_table()
print(positions.shape)
positions.head()
# Out:
# (4, 11)
#    position_id  plural_name plural_name_short singular_name  \
# 0            1  Goalkeepers               GKP    Goalkeeper
# 1            2    Defenders               DEF      Defender
# 2            3  Midfielders               MID    Midfielder
# 3            4     Forwards               FWD       Forward
#
#   singular_name_short  squad_select  squad_min_play  squad_max_play  \
# 0                 GKP             2               1               1
# 1                 DEF             5               3               5
# 2                 MID             5               2               5
# 3                 FWD             3               1               3
#
#    ui_shirt_specific  sub_positions_locked  element_count
# 0               True                    12             83
# 1              False                  <NA>            247
# 2              False                  <NA>            305
# 3              False                  <NA>             95

# %%
positions.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   position_id           4 non-null      int8
#  1   plural_name           4 non-null      object
#  2   plural_name_short     4 non-null      object
#  3   singular_name         4 non-null      object
#  4   singular_name_short   4 non-null      object
#  5   squad_select          4 non-null      int8
#  6   squad_min_play        4 non-null      int8
#  7   squad_max_play        4 non-null      int8
#  8   ui_shirt_specific     4 non-null      bool
#  9   sub_positions_locked  1 non-null      Int8
#  10  element_count         4 non-null      int16
# dtypes: Int8(1), bool(1), int16(1), int8(4), object(4)
# memory usage: 292.0+ bytes

# %%
con, cursor = sql_connection('fpl.db')
drop_table_if_exists(cursor, con, 'positions')
positions.to_sql(name='positions', con=con, if_exists='replace', index=False, dtype={'position_id': 'INTEGER PRIMARY KEY'})
con.commit()
con.close()

# %% [markdown]
# ### Elements (players)
# Information of all Premier League players including points, status, value, match stats (goals, assists, etc.), ICT index, etc.

# %%
bootstrap_static['elements'][0]
# Out:
# {'chance_of_playing_next_round': 100,
#  'chance_of_playing_this_round': 100,
#  'code': 80201,
#  'cost_change_event': 0,
#  'cost_change_event_fall': 0,
#  'cost_change_start': -5,
#  'cost_change_start_fall': 5,
#  'dreamteam_count': 1,
#  'element_type': 1,
#  'ep_next': '0.5',
#  'ep_this': '0.5',
#  'event_points': 0,
#  'first_name': 'Bernd',
#  'form': '0.0',
#  'id': 1,
#  'in_dreamteam': False,
#  'news': '',
#  'news_added': '2022-02-11T08:00:15.144286Z',
#  'now_cost': 45,
#  'photo': '80201.jpg',
#  'points_per_game': '2.5',
#  'second_name': 'Leno',
#  'selected_by_percent': '0.9',
#  'special': False,
#  'squad_number': None,
#  'status': 'a',
#  'team': 1,
#  'team_code': 3,
#  'total_points': 10,
#  'transfers_in': 80253,
#  'transfers_in_event': 26,
#  'transfers_out': 203265,
#  'transfers_out_event': 180,
#  'value_form': '0.0',
#  'value_season': '2.2',
#  'web_name': 'Leno',
#  'minutes': 360,
#  'goals_scored': 0,
#  'assists': 0,
#  'clean_sheets': 1,
#  'goals_conceded': 9,
#  'own_goals': 0,
#  'penalties_saved': 0,
#  'penalties_missed': 0,
#  'yellow_cards': 0,
#  'red_cards': 0,
#  'saves': 10,
#  'bonus': 0,
#  'bps': 69,
#  'influence': '85.0',
#  'creativity': '0.0',
#  'threat': '0.0',
#  'ict_index': '8.5',
#  'influence_rank': 388,
#  'influence_rank_type': 29,
#  'creativity_rank': 610,
#  'creativity_rank_type': 69,
#  'threat_rank': 592,
#  'threat_rank_type': 60,
#  'ict_index_rank': 438,
#  'ict_index_rank_type': 30,
#  'corners_and_indirect_freekicks_order': None,
#  'corners_and_indirect_freekicks_text': '',
#  'direct_freekicks_order': None,
#  'direct_freekicks_text': '',
#  'penalties_order': None,
#  'penalties_text': ''}

# %%
def players_table():
    bootstrap_static = get_bootstrap_static(BOOTSRAP_STATIC_URL)
    players_df = pd.DataFrame(bootstrap_static['elements'])
    players_df = (players_df
                  .assign(now_cost = players_df.now_cost.astype(float) / 10)
                  .astype({'chance_of_playing_next_round': 'Int8',
                           'chance_of_playing_this_round': 'Int8',
                           'code': 'int32',
                           'cost_change_event': 'int8',
                           'cost_change_event_fall': 'int8',
                           'cost_change_start': 'int8',
                           'cost_change_start_fall': 'int8',
                           'dreamteam_count': 'int8',
                           'element_type': 'int8',
                           'ep_next': 'float',
                           'ep_this': 'float',
                           'event_points': 'int8',
                           'form': 'float',
                           'id': 'int16',
                           'points_per_game': 'float',
                           'selected_by_percent': 'float',
                           'squad_number': 'Int8',
                           'team': 'int8',
                           'team_code': 'int8',
                           'total_points': 'int16',
                           'transfers_in': 'int32',
                           'transfers_in_event': 'int32',
                           'transfers_out': 'int32',
                           'transfers_out_event': 'int32',
                           'value_form': 'float',
                           'value_season': 'float',
                           'minutes': 'int16',
                           'goals_scored': 'int8',
                           'assists': 'int8',
                           'clean_sheets': 'int8',
                           'goals_conceded': 'int8',
                           'own_goals': 'int8',
                           'penalties_saved': 'int8',
                           'penalties_missed': 'int8',
                           'yellow_cards': 'int8',
                           'red_cards': 'int8',
                           'saves': 'int16',
                           'bonus': 'int8',
                           'bps': 'int16',
                           'influence': 'float',
                           'creativity': 'float',
                           'threat': 'float',
                           'ict_index': 'float',
                           'influence_rank': 'Int16',
                           'influence_rank_type': 'Int16',
                           'creativity_rank': 'Int16',
                           'creativity_rank_type': 'Int16',
                           'threat_rank': 'Int16',
                           'threat_rank_type': 'Int16',
                           'ict_index_rank': 'Int16',
                           'ict_index_rank_type': 'Int16',
                           'corners_and_indirect_freekicks_order': 'Int8',
                           'direct_freekicks_order': 'Int8',
                           'penalties_order': 'Int8'
                          })
                  .drop(columns=['photo'])
                  .rename(columns={'code': 'player_code',
                                   'id': 'player_id',
                                   'team': 'team_id',
                                   'element_type': 'position_id'
                                  })
                 )
    cols_to_move = ['player_id', 'player_code', 'first_name', 'second_name', 'web_name', 'team_id', 'team_code']
    players_df = players_df[cols_to_move + [ col for col in players_df.columns if col not in cols_to_move ]]
    return players_df

# %%
players = players_table()
print(players.shape)
players.head()
# Out:
# (730, 66)
#    player_id  player_code      first_name      second_name    web_name  \
# 0          1        80201           Bernd             Leno        Leno
# 1          2       115918      Rúnar Alex        Rúnarsson   Rúnarsson
# 2          3        47431         Willian  Borges Da Silva     Willian
# 3          4        54694  Pierre-Emerick       Aubameyang  Aubameyang
# 4          5        58822          Cédric           Soares      Cédric
#
#    team_id  team_code  chance_of_playing_next_round  \
# 0        1          3                           100
# 1        1          3                             0
# 2        1          3                             0
# 3        1          3                             0
# 4        1          3                           100
#
#    chance_of_playing_this_round  cost_change_event  ...  threat_rank  \
# 0                           100                  0  ...          592
# 1                             0                  0  ...          484
# 2                             0                  0  ...          725
# 3                             0                  0  ...           51
# 4                           100                  0  ...          319
#
#    threat_rank_type  ict_index_rank  ict_index_rank_type  \
# 0                60             438                   30
# 1                19             537                   54
# 2               303             725                  303
# 3                20             151                   29
# 4               104             271                   90
#
#    corners_and_indirect_freekicks_order  corners_and_indirect_freekicks_text  \
# 0                                  <NA>
# 1                                  <NA>
# 2                                  <NA>
# 3                                  <NA>
# 4                                     2
#
#    direct_freekicks_order  direct_freekicks_text  penalties_order  \
# 0                    <NA>                                    <NA>
# 1                    <NA>                                    <NA>
# 2                    <NA>                                    <NA>
# 3                    <NA>                                    <NA>
# 4                       3                                    <NA>
#
#    penalties_text
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 66 columns]

# %%
players.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 730 entries, 0 to 729
# Data columns (total 66 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             730 non-null    int16
#  1   player_code                           730 non-null    int32
#  2   first_name                            730 non-null    object
#  3   second_name                           730 non-null    object
#  4   web_name                              730 non-null    object
#  5   team_id                               730 non-null    int8
#  6   team_code                             730 non-null    int8
#  7   chance_of_playing_next_round          565 non-null    Int8
#  8   chance_of_playing_this_round          565 non-null    Int8
#  9   cost_change_event                     730 non-null    int8
#  10  cost_change_event_fall                730 non-null    int8
#  11  cost_change_start                     730 non-null    int8
#  12  cost_change_start_fall                730 non-null    int8
#  13  dreamteam_count                       730 non-null    int8
#  14  position_id                           730 non-null    int8
#  15  ep_next                               729 non-null    float64
#  16  ep_this                               729 non-null    float64
#  17  event_points                          730 non-null    int8
#  18  form                                  730 non-null    float64
#  19  in_dreamteam                          730 non-null    bool
#  20  news                                  730 non-null    object
#  21  news_added                            565 non-null    object
#  22  now_cost                              730 non-null    float64
#  23  points_per_game                       730 non-null    float64
#  24  selected_by_percent                   730 non-null    float64
#  25  special                               730 non-null    bool
#  26  squad_number                          0 non-null      Int8
#  27  status                                730 non-null    object
#  28  total_points                          730 non-null    int16
#  29  transfers_in                          730 non-null    int32
#  30  transfers_in_event                    730 non-null    int32
#  31  transfers_out                         730 non-null    int32
#  32  transfers_out_event                   730 non-null    int32
#  33  value_form                            730 non-null    float64
#  34  value_season                          730 non-null    float64
#  35  minutes                               730 non-null    int16
#  36  goals_scored                          730 non-null    int8
#  37  assists                               730 non-null    int8
#  38  clean_sheets                          730 non-null    int8
#  39  goals_conceded                        730 non-null    int8
#  40  own_goals                             730 non-null    int8
#  41  penalties_saved                       730 non-null    int8
#  42  penalties_missed                      730 non-null    int8
#  43  yellow_cards                          730 non-null    int8
#  44  red_cards                             730 non-null    int8
#  45  saves                                 730 non-null    int16
#  46  bonus                                 730 non-null    int8
#  47  bps                                   730 non-null    int16
#  48  influence                             730 non-null    float64
#  49  creativity                            730 non-null    float64
#  50  threat                                730 non-null    float64
#  51  ict_index                             730 non-null    float64
#  52  influence_rank                        729 non-null    Int16
#  53  influence_rank_type                   729 non-null    Int16
#  54  creativity_rank                       729 non-null    Int16
#  55  creativity_rank_type                  729 non-null    Int16
#  56  threat_rank                           729 non-null    Int16
#  57  threat_rank_type                      729 non-null    Int16
#  58  ict_index_rank                        729 non-null    Int16
#  59  ict_index_rank_type                   729 non-null    Int16
#  60  corners_and_indirect_freekicks_order  86 non-null     Int8
#  61  corners_and_indirect_freekicks_text   730 non-null    object
#  62  direct_freekicks_order                86 non-null     Int8
#  63  direct_freekicks_text                 730 non-null    object
#  64  penalties_order                       71 non-null     Int8
#  65  penalties_text                        730 non-null    object
# dtypes: Int16(8), Int8(6), bool(2), float64(12), int16(5), int32(5), int8(19), object(9)
# memory usage: 181.9+ KB

# %%
con, cursor = sql_connection('fpl.db')
drop_table_if_exists(cursor, con, 'players')
players.to_sql(name='players', con=con, if_exists='replace', index=False, dtype={'player_id': 'INTEGER PRIMARY KEY'})
con.commit()
con.close()

# %% [markdown]
# ### Player Stats

# %%
bootstrap_static['element_stats']
# Out:
# [{'label': 'Minutes played', 'name': 'minutes'},
#  {'label': 'Goals scored', 'name': 'goals_scored'},
#  {'label': 'Assists', 'name': 'assists'},
#  {'label': 'Clean sheets', 'name': 'clean_sheets'},
#  {'label': 'Goals conceded', 'name': 'goals_conceded'},
#  {'label': 'Own goals', 'name': 'own_goals'},
#  {'label': 'Penalties saved', 'name': 'penalties_saved'},
#  {'label': 'Penalties missed', 'name': 'penalties_missed'},
#  {'label': 'Yellow cards', 'name': 'yellow_cards'},
#  {'label': 'Red cards', 'name': 'red_cards'},
#  {'label': 'Saves', 'name': 'saves'},
#  {'label': 'Bonus', 'name': 'bonus'},
#  {'label': 'Bonus Points System', 'name': 'bps'},
#  {'label': 'Influence', 'name': 'influence'},
#  {'label': 'Creativity', 'name': 'creativity'},
#  {'label': 'Threat', 'name': 'threat'},
#  {'label': 'ICT Index', 'name': 'ict_index'}]

# %%
# Store player summary data in a dataframe
def players_stats_table():
    bootstrap_static = get_bootstrap_static(BOOTSRAP_STATIC_URL)
    player_stats_df = pd.DataFrame(bootstrap_static['element_stats'])
    player_stats_df = (player_stats_df
                       .assign(player_stat_id = player_stats_df.index + 1)
                       .astype({'player_stat_id': 'int8'})
                      )
    player_stats_df = player_stats_df[['player_stat_id', 'label', 'name']]
    return player_stats_df

# %%
player_stats = players_stats_table()
print(player_stats.shape)
player_stats.head()
# Out:
# (17, 3)
#    player_stat_id           label            name
# 0               1  Minutes played         minutes
# 1               2    Goals scored    goals_scored
# 2               3         Assists         assists
# 3               4    Clean sheets    clean_sheets
# 4               5  Goals conceded  goals_conceded

# %%
player_stats.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   player_stat_id  17 non-null     int8
#  1   label           17 non-null     object
#  2   name            17 non-null     object
# dtypes: int8(1), object(2)
# memory usage: 417.0+ bytes

# %%
con, cursor = sql_connection('fpl.db')
drop_table_if_exists(cursor, con, 'player_stats')
player_stats.to_sql(name='player_stats', con=con, if_exists='replace', index=False, dtype={'player_stat_id': 'INTEGER PRIMARY KEY'})
con.commit()
con.close()

# %% [markdown]
# ## Fixtures

# %%
# Extract information available from the fixtures end point
def get_fixtures(url):
    response = requests.get(url)
    if response.status_code == 200:
        return response.json()
    else:
        raise Exception(f"Request failed. Return code is {response.status_code}.")

# %%
fixtures = get_fixtures(FIXTURES_URL)

# %%
fixtures[0]
# Out:
# {'code': 2210271,
#  'event': 1,
#  'finished': True,
#  'finished_provisional': True,
#  'id': 1,
#  'kickoff_time': '2021-08-13T19:00:00Z',
#  'minutes': 90,
#  'provisional_start_time': False,
#  'started': True,
#  'team_a': 1,
#  'team_a_score': 0,
#  'team_h': 3,
#  'team_h_score': 2,
#  'stats': [{'identifier': 'goals_scored',
#    'a': [],
#    'h': [{'value': 1, 'element': 77}, {'value': 1, 'element': 81}]},
#   {'identifier': 'assists', 'a': [], 'h': [{'value': 1, 'element': 91}]},
#   {'identifier': 'own_goals', 'a': [], 'h': []},
#   {'identifier': 'penalties_saved', 'a': [], 'h': []},
#   {'identifier': 'penalties_missed', 'a': [], 'h': []},
#   {'identifier': 'yellow_cards', 'a': [], 'h': []},
#   {'identifier': 'red_cards', 'a': [], 'h': []},
#   {'identifier': 'saves',
#    'a': [{'value': 1, 'element': 1}],
#    'h': [{'value': 4, 'element': 80}]},
#   {'identifier': 'bonus',
#    'a': [],
#    'h': [{'value': 3, 'element': 81},
#     {'value': 2, 'element': 91},
#     {'value': 1, 'element': 80}]},
#   {'identifier': 'bps',
#    'a': [{'value': 17, 'element': 16},
#     {'value': 14, 'element': 8},
#     {'value': 14, 'element': 10},
#     {'value': 13, 'element': 7},
#     {'value': 13, 'element': 21},
#     {'value': 13, 'element': 478},
#     {'value': 12, 'element': 67},
#     {'value': 11, 'element': 1},
#     {'value': 9, 'element': 17},
#     {'value': 7, 'element': 26},
#     {'value': 4, 'element': 22},
#     {'value': 4, 'element': 531},
#     {'value': -2, 'element': 530}],
#    'h': [{'value': 33, 'element': 81},
#     {'value': 32, 'element': 91},
#     {'value': 30, 'element': 80},
#     {'value': 25, 'element': 77},
#     {'value': 23, 'element': 483},
#     {'value': 22, 'element': 76},
#     {'value': 22, 'element': 83},
#     {'value': 9, 'element': 479},
#     {'value': 6, 'element': 84},
#     {'value': 4, 'element': 78},
#     {'value': 4, 'element': 96},
#     {'value': 4, 'element': 97},
#     {'value': 3, 'element': 90},
#     {'value': 1, 'element': 88}]}],
#  'team_h_difficulty': 4,
#  'team_a_difficulty': 2,
#  'pulse_id': 66342}

# %%
# Fixtures for current gameweek
[f for f in fixtures if f['event'] == current_gameweek]
# Out:
# [{'code': 2210615,
#   'event': 35,
#   'finished': True,
#   'finished_provisional': True,
#   'id': 345,
#   'kickoff_time': '2022-04-30T11:30:00Z',
#   'minutes': 90,
#   'provisional_start_time': False,
#   'started': True,
#   'team_a': 11,
#   'team_a_score': 1,
#   'team_h': 14,
#   'team_h_score': 0,
#   'stats': [{'identifier': 'goals_scored',
#     'a': [{'value': 1, 'element': 239}],
#     'h': []},
#    {'identifier': 'assists', 'a': [{'value': 1, 'element': 240}], 'h': []},
#    {'identifier': 'own_goals', 'a': [], 'h': []},
#    {'identifier': 'penalties_saved', 'a': [], 'h': []},
#    {'identifier': 'penalties_missed', 'a': [], 'h': []},
#    {'identifier': 'yellow_cards',
#     'a': [{'value': 1, 'element': 230},
#      {'value': 1, 'element': 238},
#      {'value': 1, 'element': 240}],
#     'h': [{'value': 1, 'element': 310}]},
#    {'identifier': 'red_cards', 'a': [], 'h': []},
#    {'identifier': 'saves',
#     'a': [{'value': 2, 'element': 231}],
#     'h': [{'value': 9, 'element': 295}]},
#    {'identifier': 'bonus',
#     'a': [{'value': 3, 'element': 231}, {'value': 2, 'element': 239}],
#     'h': [{'value': 2, 'element': 295}]},
#    {'identifier': 'bps',
#     'a': [{'value': 29, 'element': 231},
#      {'value': 27, 'element': 239},
#      {'value': 26, 'element': 234},
#      {'value': 25, 'element': 224},
#      {'value': 23, 'element': 229},
#      {'value': 23, 'element': 238},
#      {'value': 17, 'element': 221},
#      {'value': 17, 'element': 222},
#      {'value': 16, 'element': 240},
#      {'value': 11, 'element': 696},
#      {'value': 3, 'element': 225},
#      {'value': 1, 'element': 232},
#      {'value': 1, 'element': 233},
#      {'value': -2, 'element': 230}],
#     'h': [{'value': 27, 'element': 295},
#      {'value': 17, 'element': 39},
#      {'value': 11, 'element': 303},
#      {'value': 10, 'element': 58},
#      {'value': 9, 'element': 291},
#      {'value': 8, 'element': 697},
#      {'value': 6, 'element': 305},
#      {'value': 5, 'element': 308},
#      {'value': 4, 'element': 19},
#      {'value': 4, 'element': 299},
#      {'value': 4, 'element': 307},
#      {'value': 3, 'element': 304},
#      {'value': 2, 'element': 310},
#      {'value': 1, 'element': 109}]}],
#   'team_h_difficulty': 4,
#   'team_a_difficulty': 3,
#   'pulse_id': 66686},
#  {'code': 2210611,
#   'event': 35,
#   'finished': True,
#   'finished_provisional': True,
#   'id': 341,
#   'kickoff_time': '2022-04-30T14:00:00Z',
#   'minutes': 90,
#   'provisional_start_time': False,
#   'started': True,
#   'team_a': 15,
#   'team_a_score': 0,
#   'team_h': 2,
#   'team_h_score': 2,
#   'stats': [{'identifier': 'goals_scored',
#     'a': [],
#     'h': [{'value': 1, 'element': 40}, {'value': 1, 'element': 337}]},
#    {'identifier': 'assists',
#     'a': [],
#     'h': [{'value': 1, 'element': 43}, {'value': 1, 'element': 337}]},
#    {'identifier': 'own_goals', 'a': [], 'h': []},
#    {'identifier': 'penalties_saved', 'a': [], 'h': []},
#    {'identifier': 'penalties_missed', 'a': [], 'h': []},
#    {'identifier': 'yellow_cards',
#     'a': [{'value': 1, 'element': 326}],
#     'h': [{'value': 1, 'element': 10},
#      {'value': 1, 'element': 51},
#      {'value': 1, 'element': 337},
#      {'value': 1, 'element': 638}]},
#    {'identifier': 'red_cards', 'a': [], 'h': []},
#    {'identifier': 'saves',
#     'a': [{'value': 4, 'element': 314}],
#     'h': [{'value': 3, 'element': 30}]},
#    {'identifier': 'bonus',
#     'a': [],
#     'h': [{'value': 3, 'element': 40},
#      {'value': 2, 'element': 168},
#      {'value': 1, 'element': 337}]},
#    {'identifier': 'bps',
#     'a': [{'value': 20, 'element': 314},
#      {'value': 17, 'element': 321},
#      {'value': 14, 'element': 145},
#      {'value': 14, 'element': 290},
#      {'value': 12, 'element': 319},
#      {'value': 7, 'element': 323},
#      {'value': 7, 'element': 581},
#      {'value': 6, 'element': 449},
#      {'value': 5, 'element': 326},
#      {'value': 5, 'element': 471},
#      {'value': 4, 'element': 516},
#      {'value': 3, 'element': 315},
#      {'value': -1, 'element': 648}],
#     'h': [{'value': 34, 'element': 40},
#      {'value': 32, 'element': 168},
#      {'value': 29, 'element': 337},
#      {'value': 26, 'element': 30},
#      {'value': 24, 'element': 38},
#      {'value': 23, 'element': 10},
#      {'value': 22, 'element': 44},
#      {'value': 19, 'element': 43},
#      {'value': 17, 'element': 35},
#      {'value': 13, 'element': 681},
#      {'value': 8, 'element': 638},
#      {'value': 5, 'element': 51},
#      {'value': 3, 'element': 50},
#      {'value': -2, 'element': 492}]}],
#   'team_h_difficulty': 2,
#   'team_a_difficulty': 2,
#   'pulse_id': 66682},
#  {'code': 2210616,
#   'event': 35,
#   'finished': True,
#   'finished_provisional': True,
#   'id': 346,
#   'kickoff_time': '2022-04-30T14:00:00Z',
#   'minutes': 90,
#   'provisional_start_time': False,
#   'started': True,
#   'team_a': 7,
#   'team_a_score': 2,
#   'team_h': 16,
#   'team_h_score': 1,
#   'stats': [{'identifier': 'goals_scored',
#     'a': [{'value': 1, 'element': 154}, {'value': 1, 'element': 160}],
#     'h': [{'value': 1, 'element': 335}]},
#    {'identifier': 'assists',
#     'a': [{'value': 1, 'element': 148}, {'value': 1, 'element': 493}],
#     'h': [{'value': 1, 'element': 341}]},
#    {'identifier': 'own_goals', 'a': [], 'h': []},
#    {'identifier': 'penalties_saved', 'a': [], 'h': []},
#    {'identifier': 'penalties_missed', 'a': [], 'h': []},
#    {'identifier': 'yellow_cards',
#     'a': [{'value': 1, 'element': 148},
#      {'value': 1, 'element': 159},
#      {'value': 1, 'element': 474}],
#     'h': [{'value': 1, 'element': 343}]},
#    {'identifier': 'red_cards', 'a': [], 'h': []},
#    {'identifier': 'saves',
#     'a': [{'value': 2, 'element': 146}],
#     'h': [{'value': 3, 'element': 333}]},
#    {'identifier': 'bonus',
#     'a': [{'value': 2, 'element': 160}, {'value': 1, 'element': 493}],
#     'h': [{'value': 3, 'element': 335}]},
#    {'identifier': 'bps',
#     'a': [{'value': 29, 'element': 160},
#      {'value': 25, 'element': 493},
#      {'value': 24, 'element': 154},
#      {'value': 23, 'element': 148},
#      {'value': 19, 'element': 488},
#      {'value': 17, 'element': 477},
#      {'value': 16, 'element': 146},
#      {'value': 16, 'element': 155},
#      {'value': 11, 'element': 144},
#      {'value': 11, 'element': 474},
#      {'value': 3, 'element': 464},
#      {'value': 2, 'element': 386},
#      {'value': -1, 'element': 153},
#      {'value': -4, 'element': 159}],
#     'h': [{'value': 34, 'element': 335},
#      {'value': 24, 'element': 341},
#      {'value': 16, 'element': 342},
#      {'value': 15, 'element': 333},
#      {'value': 12, 'element': 351},
#      {'value': 11, 'element': 336},
#      {'value': 10, 'element': 346},
#      {'value': 7, 'element': 460},
#      {'value': 6, 'element': 343},
#      {'value': 6, 'element': 345},
#      {'value': 4, 'element': 339},
#      {'value': 4, 'element': 517},
#      {'value': 2, 'element': 518},
#      {'value': 2, 'element': 519}]}],
#   'team_h_difficulty': 2,
#   'team_a_difficulty': 3,
#   'pulse_id': 66687},
#  {'code': 2210618,
#   'event': 35,
#   'finished': True,
#   'finished_provisional': True,
#   'id': 348,
#   'kickoff_time': '2022-04-30T14:00:00Z',
#   'minutes': 90,
#   'provisional_start_time': False,
#   'started': True,
#   'team_a': 5,
#   'team_a_score': 2,
#   'team_h': 18,
#   'team_h_score': 1,
#   'stats': [{'identifier': 'goals_scored',
#     'a': [{'value': 1, 'element': 101}, {'value': 1, 'element': 115}],
#     'h': []},
#    {'identifier': 'assists',
#     'a': [{'value': 1, 'element': 111}, {'value': 1, 'element': 113}],
#     'h': [{'value': 1, 'element': 495}]},
#    {'identifier': 'own_goals', 'a': [{'value': 1, 'element': 98}], 'h': []},
#    {'identifier': 'penalties_saved', 'a': [], 'h': []},
#    {'identifier': 'penalties_missed', 'a': [], 'h': []},
#    {'identifier': 'yellow_cards',
#     'a': [{'value': 1, 'element': 98}, {'value': 1, 'element': 451}],
#     'h': [{'value': 1, 'element': 495}]},
#    {'identifier': 'red_cards', 'a': [], 'h': []},
#    {'identifier': 'saves',
#     'a': [{'value': 1, 'element': 112}],
#     'h': [{'value': 4, 'element': 376}]},
#    {'identifier': 'bonus',
#     'a': [{'value': 3, 'element': 101},
#      {'value': 3, 'element': 115},
#      {'value': 1, 'element': 113}],
#     'h': []},
#    {'identifier': 'bps',
#     'a': [{'value': 28, 'element': 101},
#      {'value': 28, 'element': 115},
#      {'value': 25, 'element': 113},
#      {'value': 20, 'element': 585},
#      {'value': 15, 'element': 111},
#      {'value': 13, 'element': 112},
#      {'value': 10, 'element': 118},
#      {'value': 9, 'element': 575},
#      {'value': 7, 'element': 451},
#      {'value': 3, 'element': 102},
#      {'value': 3, 'element': 110},
#      {'value': 2, 'element': 98},
#      {'value': 2, 'element': 700}],
#     'h': [{'value': 17, 'element': 376},
#      {'value': 12, 'element': 382},
#      {'value': 12, 'element': 495},
#      {'value': 12, 'element': 676},
#      {'value': 12, 'element': 677},
#      {'value': 11, 'element': 354},
#      {'value': 9, 'element': 403},
#      {'value': 8, 'element': 384},
#      {'value': 8, 'element': 399},
#      {'value': 6, 'element': 404},
#      {'value': 4, 'element': 450}]}],
#   'team_h_difficulty': 2,
#   'team_a_difficulty': 2,
#   'pulse_id': 66689},
#  {'code': 2210620,
#   'event': 35,
#   'finished': True,
#   'finished_provisional': True,
#   'id': 350,
#   'kickoff_time': '2022-04-30T14:00:00Z',
#   'minutes': 90,
#   'provisional_start_time': False,
#   'started': True,
#   'team_a': 4,
#   'team_a_score': 3,
#   'team_h': 20,
#   'team_h_score': 0,
#   'stats': [{'identifier': 'goals_scored',
#     'a': [{'value': 1, 'element': 64},
#      {'value': 1, 'element': 70},
#      {'value': 1, 'element': 74}],
#     'h': []},
#    {'identifier': 'assists', 'a': [{'value': 2, 'element': 447}], 'h': []},
#    {'identifier': 'own_goals', 'a': [], 'h': []},
#    {'identifier': 'penalties_saved', 'a': [], 'h': []},
#    {'identifier': 'penalties_missed',
#     'a': [{'value': 1, 'element': 74}],
#     'h': []},
#    {'identifier': 'yellow_cards',
#     'a': [{'value': 1, 'element': 584}],
#     'h': [{'value': 1, 'element': 429}, {'value': 1, 'element': 583}]},
#    {'identifier': 'red_cards', 'a': [], 'h': []},
#    {'identifier': 'saves',
#     'a': [{'value': 1, 'element': 69}],
#     'h': [{'value': 6, 'element': 475}]},
#    {'identifier': 'bonus',
#     'a': [{'value': 3, 'element': 70},
#      {'value': 3, 'element': 447},
#      {'value': 1, 'element': 584}],
#     'h': []},
#    {'identifier': 'bps',
#     'a': [{'value': 31, 'element': 70},
#      {'value': 31, 'element': 447},
#      {'value': 30, 'element': 584},
#      {'value': 29, 'element': 64},
#      {'value': 28, 'element': 59},
#      {'value': 28, 'element': 538},
#      {'value': 25, 'element': 62},
#      {'value': 24, 'element': 74},
#      {'value': 22, 'element': 69},
#      {'value': 12, 'element': 462},
#      {'value': 8, 'element': 60},
#      {'value': 5, 'element': 61},
#      {'value': 4, 'element': 55},
#      {'value': 3, 'element': 71}],
#     'h': [{'value': 23, 'element': 475},
#      {'value': 17, 'element': 426},
#      {'value': 13, 'element': 434},
#      {'value': 12, 'element': 428},
#      {'value': 12, 'element': 429},
#      {'value': 11, 'element': 431},
#      {'value': 10, 'element': 470},
#      {'value': 9, 'element': 436},
#      {'value': 7, 'element': 583},
#      {'value': 5, 'element': 441},
#      {'value': 3, 'element': 437},
#      {'value': 1, 'element': 430},
#      {'value': -1, 'element': 433}]}],
#   'team_h_difficulty': 2,
#   'team_a_difficulty': 3,
#   'pulse_id': 66691},
#  {'code': 2210613,
#   'event': 35,
#   'finished': True,
#   'finished_provisional': True,
#   'id': 343,
#   'kickoff_time': '2022-04-30T16:30:00Z',
#   'minutes': 90,
#   'provisional_start_time': False,
#   'started': True,
#   'team_a': 12,
#   'team_a_score': 4,
#   'team_h': 10,
#   'team_h_score': 0,
#   'stats': [{'identifier': 'goals_scored',
#     'a': [{'value': 1, 'element': 258},
#      {'value': 1, 'element': 263},
#      {'value': 1, 'element': 266},
#      {'value': 1, 'element': 453}],
#     'h': []},
#    {'identifier': 'assists',
#     'a': [{'value': 2, 'element': 265}, {'value': 1, 'element': 262}],
#     'h': []},
#    {'identifier': 'own_goals', 'a': [], 'h': []},
#    {'identifier': 'penalties_saved', 'a': [], 'h': []},
#    {'identifier': 'penalties_missed', 'a': [], 'h': []},
#    {'identifier': 'yellow_cards',
#     'a': [{'value': 1, 'element': 33}, {'value': 1, 'element': 256}],
#     'h': [{'value': 1, 'element': 463}]},
#    {'identifier': 'red_cards', 'a': [], 'h': []},
#    {'identifier': 'saves',
#     'a': [{'value': 1, 'element': 257}],
#     'h': [{'value': 2, 'element': 199}]},
#    {'identifier': 'bonus',
#     'a': [{'value': 3, 'element': 262},
#      {'value': 2, 'element': 263},
#      {'value': 1, 'element': 266}],
#     'h': []},
#    {'identifier': 'bps',
#     'a': [{'value': 43, 'element': 262},
#      {'value': 42, 'element': 263},
#      {'value': 38, 'element': 266},
#      {'value': 33, 'element': 265},
#      {'value': 29, 'element': 259},
#      {'value': 25, 'element': 256},
#      {'value': 23, 'element': 257},
#      {'value': 21, 'element': 453},
#      {'value': 18, 'element': 258},
#      {'value': 13, 'element': 250},
#      {'value': 6, 'element': 33},
#      {'value': 5, 'element': 261},
#      {'value': 1, 'element': 255}],
#     'h': [{'value': 17, 'element': 198},
#      {'value': 15, 'element': 186},
#      {'value': 15, 'element': 194},
#      {'value': 12, 'element': 267},
#      {'value': 11, 'element': 191},
#      {'value': 11, 'element': 199},
#      {'value': 8, 'element': 187},
#      {'value': 8, 'element': 196},
#      {'value': 7, 'element': 185},
#      {'value': 3, 'element': 287},
#      {'value': 3, 'element': 463},
#      {'value': 3, 'element': 550},
#      {'value': 3, 'element': 577},
#      {'value': -2, 'element': 188}]}],
#   'team_h_difficulty': 5,
#   'team_a_difficulty': 2,
#   'pulse_id': 66684},
#  {'code': 2210612,
#   'event': 35,
#   'finished': False,
#   'finished_provisional': True,
#   'id': 342,
#   'kickoff_time': '2022-05-01T13:00:00Z',
#   'minutes': 90,
#   'provisional_start_time': False,
#   'started': True,
#   'team_a': 6,
#   'team_a_score': 0,
#   'team_h': 8,
#   'team_h_score': 1,
#   'stats': [{'identifier': 'goals_scored',
#     'a': [],
#     'h': [{'value': 1, 'element': 180}]},
#    {'identifier': 'assists', 'a': [], 'h': [{'value': 1, 'element': 484}]},
#    {'identifier': 'own_goals', 'a': [], 'h': []},
#    {'identifier': 'penalties_saved', 'a': [], 'h': []},
#    {'identifier': 'penalties_missed', 'a': [], 'h': []},
#    {'identifier': 'yellow_cards',
#     'a': [{'value': 1, 'element': 119},
#      {'value': 1, 'element': 122},
#      {'value': 1, 'element': 127},
#      {'value': 1, 'element': 138},
#      {'value': 1, 'element': 141}],
#     'h': [{'value': 1, 'element': 163},
#      {'value': 1, 'element': 165},
#      {'value': 1, 'element': 178}]},
#    {'identifier': 'red_cards', 'a': [], 'h': []},
#    {'identifier': 'saves',
#     'a': [{'value': 3, 'element': 143}],
#     'h': [{'value': 5, 'element': 170}]},
#    {'identifier': 'bonus', 'a': [], 'h': []},
#    {'identifier': 'bps',
#     'a': [{'value': 19, 'element': 132},
#      {'value': 16, 'element': 121},
#      {'value': 14, 'element': 142},
#      {'value': 14, 'element': 143},
#      {'value': 13, 'element': 122},
#      {'value': 12, 'element': 123},
#      {'value': 12, 'element': 125},
#      {'value': 8, 'element': 138},
#      {'value': 7, 'element': 119},
#      {'value': 5, 'element': 134},
#      {'value': 3, 'element': 127},
#      {'value': 3, 'element': 141},
#      {'value': 2, 'element': 131},
#      {'value': 2, 'element': 137}],
#     'h': [{'value': 31, 'element': 170},
#      {'value': 30, 'element': 180},
#      {'value': 24, 'element': 484},
#      {'value': 23, 'element': 175},
#      {'value': 19, 'element': 165},
#      {'value': 19, 'element': 178},
#      {'value': 16, 'element': 173},
#      {'value': 15, 'element': 675},
#      {'value': 13, 'element': 174},
#      {'value': 4, 'element': 163},
#      {'value': 4, 'element': 171},
#      {'value': 3, 'element': 503},
#      {'value': 3, 'element': 591},
#      {'value': 2, 'element': 363}]}],
#   'team_h_difficulty': 4,
#   'team_a_difficulty': 2,
#   'pulse_id': 66683},
#  {'code': 2210617,
#   'event': 35,
#   'finished': False,
#   'finished_provisional': True,
#   'id': 347,
#   'kickoff_time': '2022-05-01T13:00:00Z',
#   'minutes': 90,
#   'provisional_start_time': False,
#   'started': True,
#   'team_a': 9,
#   'team_a_score': 1,
#   'team_h': 17,
#   'team_h_score': 3,
#   'stats': [{'identifier': 'goals_scored',
#     'a': [{'value': 1, 'element': 213}],
#     'h': [{'value': 2, 'element': 359}, {'value': 1, 'element': 357}]},
#    {'identifier': 'assists',
#     'a': [{'value': 1, 'element': 210}],
#     'h': [{'value': 2, 'element': 701}, {'value': 1, 'element': 359}]},
#    {'identifier': 'own_goals', 'a': [], 'h': []},
#    {'identifier': 'penalties_saved', 'a': [], 'h': []},
#    {'identifier': 'penalties_missed', 'a': [], 'h': []},
#    {'identifier': 'yellow_cards',
#     'a': [{'value': 1, 'element': 202},
#      {'value': 1, 'element': 208},
#      {'value': 1, 'element': 219}],
#     'h': [{'value': 1, 'element': 364}, {'value': 1, 'element': 702}]},
#    {'identifier': 'red_cards', 'a': [], 'h': []},
#    {'identifier': 'saves',
#     'a': [{'value': 4, 'element': 200}],
#     'h': [{'value': 1, 'element': 353}]},
#    {'identifier': 'bonus', 'a': [], 'h': []},
#    {'identifier': 'bps',
#     'a': [{'value': 29, 'element': 213},
#      {'value': 18, 'element': 209},
#      {'value': 17, 'element': 200},
#      {'value': 16, 'element': 217},
#      {'value': 13, 'element': 210},
#      {'value': 12, 'element': 203},
#      {'value': 11, 'element': 219},
#      {'value': 10, 'element': 208},
#      {'value': 6, 'element': 202},
#      {'value': 6, 'element': 458},
#      {'value': 4, 'element': 211},
#      {'value': 3, 'element': 455},
#      {'value': 2, 'element': 646},
#      {'value': 1, 'element': 205}],
#     'h': [{'value': 59, 'element': 359},
#      {'value': 26, 'element': 701},
#      {'value': 21, 'element': 357},
#      {'value': 21, 'element': 365},
#      {'value': 17, 'element': 702},
#      {'value': 16, 'element': 494},
#      {'value': 12, 'element': 361},
#      {'value': 12, 'element': 588},
#      {'value': 11, 'element': 364},
#      {'value': 9, 'element': 353},
#      {'value': 9, 'element': 368},
#      {'value': 3, 'element': 366},
#      {'value': 1, 'element': 369},
#      {'value': -3, 'element': 362}]}],
#   'team_h_difficulty': 2,
#   'team_a_difficulty': 4,
#   'pulse_id': 66688},
#  {'code': 2210619,
#   'event': 35,
#   'finished': False,
#   'finished_provisional': True,
#   'id': 349,
#   'kickoff_time': '2022-05-01T15:30:00Z',
#   'minutes': 90,
#   'provisional_start_time': False,
#   'started': True,
#   'team_a': 1,
#   'team_a_score': 2,
#   'team_h': 19,
#   'team_h_score': 1,
#   'stats': [{'identifier': 'goals_scored',
#     'a': [{'value': 1, 'element': 14}, {'value': 1, 'element': 23}],
#     'h': [{'value': 1, 'element': 420}]},
#    {'identifier': 'assists',
#     'a': [{'value': 1, 'element': 22}, {'value': 1, 'element': 26}],
#     'h': [{'value': 1, 'element': 418}]},
#    {'identifier': 'own_goals', 'a': [], 'h': []},
#    {'identifier': 'penalties_saved', 'a': [], 'h': []},
#    {'identifier': 'penalties_missed', 'a': [], 'h': []},
#    {'identifier': 'yellow_cards',
#     'a': [{'value': 1, 'element': 20}, {'value': 1, 'element': 22}],
#     'h': [{'value': 1, 'element': 411}, {'value': 1, 'element': 420}]},
#    {'identifier': 'red_cards', 'a': [], 'h': []},
#    {'identifier': 'saves',
#     'a': [{'value': 2, 'element': 559}],
#     'h': [{'value': 5, 'element': 408}]},
#    {'identifier': 'bonus', 'a': [], 'h': []},
#    {'identifier': 'bps',
#     'a': [{'value': 33, 'element': 23},
#      {'value': 28, 'element': 14},
#      {'value': 22, 'element': 26},
#      {'value': 15, 'element': 12},
#      {'value': 14, 'element': 7},
#      {'value': 13, 'element': 22},
#      {'value': 13, 'element': 466},
#      {'value': 13, 'element': 558},
#      {'value': 12, 'element': 559},
#      {'value': 10, 'element': 590},
#      {'value': 9, 'element': 20},
#      {'value': 3, 'element': 21},
#      {'value': 2, 'element': 5},
#      {'value': 2, 'element': 478}],
#     'h': [{'value': 21, 'element': 418},
#      {'value': 18, 'element': 408},
#      {'value': 17, 'element': 420},
#      {'value': 16, 'element': 406},
#      {'value': 15, 'element': 416},
#      {'value': 13, 'element': 421},
#      {'value': 12, 'element': 128},
#      {'value': 11, 'element': 415},
#      {'value': 10, 'element': 411},
#      {'value': 9, 'element': 419},
#      {'value': 8, 'element': 423},
#      {'value': 4, 'element': 412},
#      {'value': 3, 'element': 422}]}],
#   'team_h_difficulty': 4,
#   'team_a_difficulty': 3,
#   'pulse_id': 66690},
#  {'code': 2210614,
#   'event': 35,
#   'finished': False,
#   'finished_provisional': False,
#   'id': 344,
#   'kickoff_time': '2022-05-02T19:00:00Z',
#   'minutes': 0,
#   'provisional_start_time': False,
#   'started': False,
#   'team_a': 3,
#   'team_a_score': None,
#   'team_h': 13,
#   'team_h_score': None,
#   'stats': [],
#   'team_h_difficulty': 2,
#   'team_a_difficulty': 4,
#   'pulse_id': 66685}]

# %%
def fixtures_table():
    response = get_fixtures(FIXTURES_URL)
    fixtures_df = pd.DataFrame(response)
    fixtures_df = (fixtures_df
                   .drop(columns=['stats']) # extracting fixture stats left as an exercise
                   .astype({'code': 'int32',
                            'event': 'Int8',
                            'id': 'int16',
                            'minutes': 'int8',
                            'team_h': 'int8',
                            'team_a': 'int8',
                            'team_a_score': 'Int8',
                            'team_h_score': 'Int8',
                            'team_h_difficulty': 'int8',
                            'team_a_difficulty': 'int8',
                            'pulse_id': 'int32'
                           })
                   .rename(columns={'code': 'fixture_code',
                                    'event': 'gameweek',
                                    'id': 'fixture_id',
                                    'team_h': 'home_team_id',
                                    'team_a': 'away_team_id'
                                   })
                  )
    cols_to_move = ['fixture_id', 'fixture_code', 'gameweek']
    fixtures_df = fixtures_df[cols_to_move + [ col for col in fixtures_df.columns if col not in cols_to_move ]]
    return fixtures_df

# %%
fixtures = fixtures_table()
print(fixtures.shape)
fixtures.head()
# Out:
# (380, 16)
#    fixture_id  fixture_code  gameweek  finished  finished_provisional  \
# 0           1       2210271         1      True                  True
# 1           6       2210276         1      True                  True
# 2           2       2210272         1      True                  True
# 3           3       2210273         1      True                  True
# 4           4       2210274         1      True                  True
#
#            kickoff_time  minutes  provisional_start_time  started  \
# 0  2021-08-13T19:00:00Z       90                   False     True
# 1  2021-08-14T11:30:00Z       90                   False     True
# 2  2021-08-14T14:00:00Z       90                   False     True
# 3  2021-08-14T14:00:00Z       90                   False     True
# 4  2021-08-14T14:00:00Z       90                   False     True
#
#    away_team_id  team_a_score  home_team_id  team_h_score  team_h_difficulty  \
# 0             1             0             3             2                  4
# 1            10             1            13             5                  2
# 2             4             2             5             1                  2
# 3             7             0             6             3                  2
# 4            16             1             8             3                  2
#
#    team_a_difficulty  pulse_id
# 0                  2     66342
# 1                  4     66347
# 2                  2     66343
# 3                  4     66344
# 4                  2     66345

# %%
fixtures.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fixture_id              380 non-null    int16
#  1   fixture_code            380 non-null    int32
#  2   gameweek                380 non-null    Int8
#  3   finished                380 non-null    bool
#  4   finished_provisional    380 non-null    bool
#  5   kickoff_time            380 non-null    object
#  6   minutes                 380 non-null    int8
#  7   provisional_start_time  380 non-null    bool
#  8   started                 380 non-null    bool
#  9   away_team_id            380 non-null    int8
#  10  team_a_score            341 non-null    Int8
#  11  home_team_id            380 non-null    int8
#  12  team_h_score            341 non-null    Int8
#  13  team_h_difficulty       380 non-null    int8
#  14  team_a_difficulty       380 non-null    int8
#  15  pulse_id                380 non-null    int32
# dtypes: Int8(3), bool(4), int16(1), int32(2), int8(5), object(1)
# memory usage: 12.4+ KB

# %%
con, cursor = sql_connection('fpl.db')
drop_table_if_exists(cursor, con, 'fixtures')
fixtures.to_sql(name='fixtures', con=con, if_exists='replace', index=False, dtype={'fixture_id': 'INTEGER PRIMARY KEY',
                                                                                   'finished': 'INT',
                                                                                   'finished_provisional': 'INT',
                                                                                   'started': 'INT'
                                                                                  })
con.commit()
con.close()

# %% [markdown]
# ## Summary
# We have extracted fantasy premier league data using the API, transformed the data using pandas, and loaded the data into a SQLite database. In part 2, we will query the database and compare SQL queries with pandas equivalents.
