# %% [markdown]
# # Storing Fantasy Premier League data in a database - part 2
# - Author: Steffan Rees
# - 19/04/2022

# %% [markdown]
# ## Background
# This notebook follows on from **Storing Fantasy Premier League data in a database - part 1** where we extracted fantasy premier league data from the API and stored the transformed data in a SQLite database.
#
# In this notebook we will query the data using SQL and pandas.
#
# It's worth noting that the database and its tables can also be accessed using SQLite Studio.
#
# Pandas has a guide for comparing pandas operations with SQL https://pandas.pydata.org/docs/getting_started/comparison/comparison_with_sql.html.

# %%
# Import libraries
import pandas as pd
import sqlite3
from pandasql import sqldf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re

# %%
# Connect to the database
def sql_connection(db):
    try:
        con = sqlite3.connect(db)
    except Error:
        print(Error)
        
    cursor = con.cursor()
    return con, cursor

# %%
con, cursor = sql_connection('fpl.db')

# %% [markdown]
# ## List the tables in the database

# %%
# Using SQLite
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
print(cursor.fetchall())
# Out:
# [('gameweeks',), ('teams',), ('positions',), ('players',), ('player_stats',), ('fixtures',)]

# %%
# Using pandas
pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", con)
# Out:
#            name
# 0     gameweeks
# 1         teams
# 2     positions
# 3       players
# 4  player_stats
# 5      fixtures

# %% [markdown]
# ## Import data into dataframe

# %% [markdown]
# ### Teams

# %%
teams = pd.read_sql_query("SELECT * FROM teams", con)
print(teams.shape)
teams.head()
# Out:
# (20, 21)
#    team_id  team_code    team_name team_short_name  draw  form  loss  played  \
# 0        1          3      Arsenal             ARS     0  None     0       0
# 1        2          7  Aston Villa             AVL     0  None     0       0
# 2        3         94    Brentford             BRE     0  None     0       0
# 3        4         36     Brighton             BHA     0  None     0       0
# 4        5         90      Burnley             BUR     0  None     0       0
#
#    points  position  ...  team_division unavailable  win  \
# 0       0         0  ...           None           0    0
# 1       0         0  ...           None           0    0
# 2       0         0  ...           None           0    0
# 3       0         0  ...           None           0    0
# 4       0         0  ...           None           0    0
#
#    strength_overall_home  strength_overall_away  strength_attack_home  \
# 0                   1250                   1270                  1150
# 1                   1100                   1100                  1140
# 2                   1060                   1070                  1120
# 3                   1100                   1090                  1160
# 4                   1060                   1060                  1080
#
#    strength_attack_away  strength_defence_home  strength_defence_away  \
# 0                  1210                   1190                   1220
# 1                  1110                   1090                   1090
# 2                  1150                   1080                   1120
# 3                  1160                   1100                   1120
# 4                  1130                   1060                   1100
#
#    pulse_id
# 0         1
# 1         2
# 2       130
# 3       131
# 4        43
#
# [5 rows x 21 columns]

# %%
teams.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   team_id                20 non-null     int64
#  1   team_code              20 non-null     int64
#  2   team_name              20 non-null     object
#  3   team_short_name        20 non-null     object
#  4   draw                   20 non-null     int64
#  5   form                   0 non-null      object
#  6   loss                   20 non-null     int64
#  7   played                 20 non-null     int64
#  8   points                 20 non-null     int64
#  9   position               20 non-null     int64
#  10  strength               20 non-null     int64
#  11  team_division          0 non-null      object
#  12  unavailable            20 non-null     int64
#  13  win                    20 non-null     int64
#  14  strength_overall_home  20 non-null     int64
#  15  strength_overall_away  20 non-null     int64
#  16  strength_attack_home   20 non-null     int64
#  17  strength_attack_away   20 non-null     int64
#  18  strength_defence_home  20 non-null     int64
#  19  strength_defence_away  20 non-null     int64
#  20  pulse_id               20 non-null     int64
# dtypes: int64(17), object(4)
# memory usage: 3.4+ KB

# %% [markdown]
# ### Gameweeks

# %%
gameweeks = pd.read_sql_query("SELECT * FROM gameweeks", con, dtype={'highest_scoring_entry_id': 'Int32',
                                                                     'highest_score': 'Int32',
                                                                     'most_selected_id': 'Int32',
                                                                     'most_transferred_in_id': 'Int32',
                                                                     'top_player_id': 'Int32',
                                                                     'most_captained_id': 'Int32',
                                                                     'most_vice_captained_id': 'Int32',
                                                                     'most_points_score': 'Int8',
                                                                     'bboost_played': 'Int32',
                                                                     'freehit_played': 'Int32',
                                                                     'wildcard_played': 'Int32',
                                                                     'triple_captain_played': 'Int32'
                                                                    })
print(gameweeks.shape)
gameweeks.head()
# Out:
# (38, 26)
#    gameweek_id gameweek_name         deadline_time  average_entry_score  \
# 0            1    Gameweek 1  2021-08-13T17:30:00Z                   69
# 1            2    Gameweek 2  2021-08-21T10:00:00Z                   56
# 2            3    Gameweek 3  2021-08-28T10:00:00Z                   54
# 3            4    Gameweek 4  2021-09-11T10:00:00Z                   57
# 4            5    Gameweek 5  2021-09-17T17:30:00Z                   55
#
#    finished  data_checked  highest_scoring_entry_id  deadline_time_epoch  \
# 0         1             1                   5059647           1628875800
# 1         1             1                   6882931           1629540000
# 2         1             1                   7516002           1630144800
# 3         1             1                   7797969           1631354400
# 4         1             1                   3139954           1631899800
#
#    deadline_time_game_offset  highest_score  ...  most_transferred_in_id  \
# 0                          0            150  ...                       1
# 1                          0            146  ...                     272
# 2                          0            119  ...                     419
# 3                          0            120  ...                     579
# 4                          0            144  ...                     579
#
#    top_player_id  transfers_made  most_captained_id  most_vice_captained_id  \
# 0            277               0                233                     277
# 1            142        12038724                233                     277
# 2            268        15553648                277                     277
# 3            432        28985870                233                     233
# 4             44        18706283                233                     579
#
#    most_points_score  bboost_played  freehit_played  wildcard_played  \
# 0                 20         145658            <NA>             <NA>
# 1                 18          95038          102410           277209
# 2                 18          94049          117627           372083
# 3                 13          77204          168976          1117718
# 4                 15          49533          127510           708431
#
#    triple_captain_played
# 0                 225749
# 1                 269514
# 2                 138714
# 3                 157121
# 4                 104192
#
# [5 rows x 26 columns]

# %%
gameweeks.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   gameweek_id                38 non-null     int64
#  1   gameweek_name              38 non-null     object
#  2   deadline_time              38 non-null     object
#  3   average_entry_score        38 non-null     int64
#  4   finished                   38 non-null     int64
#  5   data_checked               38 non-null     int64
#  6   highest_scoring_entry_id   37 non-null     Int32
#  7   deadline_time_epoch        38 non-null     int64
#  8   deadline_time_game_offset  38 non-null     int64
#  9   highest_score              37 non-null     Int32
#  10  is_previous                38 non-null     int64
#  11  is_current                 38 non-null     int64
#  12  is_next                    38 non-null     int64
#  13  cup_leagues_created        38 non-null     int64
#  14  h2h_ko_matches_created     38 non-null     int64
#  15  most_selected_id           37 non-null     Int32
#  16  most_transferred_in_id     37 non-null     Int32
#  17  top_player_id              37 non-null     Int32
#  18  transfers_made             38 non-null     int64
#  19  most_captained_id          37 non-null     Int32
#  20  most_vice_captained_id     37 non-null     Int32
#  21  most_points_score          37 non-null     Int8
#  22  bboost_played              37 non-null     Int32
#  23  freehit_played             36 non-null     Int32
#  24  wildcard_played            36 non-null     Int32
#  25  triple_captain_played      37 non-null     Int32
# dtypes: Int32(11), Int8(1), int64(12), object(2)
# memory usage: 6.4+ KB

# %% [markdown]
# ### Fixtures

# %%
fixtures = pd.read_sql_query("SELECT * FROM fixtures", con, dtype={'gameweek_id': 'Int8',
                                                                   'started': 'Int8',
                                                                   'away_team_score': 'Int8',
                                                                   'home_team_score': 'Int8'
                                                                  })
print(fixtures.shape)
fixtures.head()
# Out:
# (380, 16)
#    fixture_id  fixture_code  gameweek_id  finished  finished_provisional  \
# 0           1       2210271            1         1                     1
# 1           2       2210272            1         1                     1
# 2           3       2210273            1         1                     1
# 3           4       2210274            1         1                     1
# 4           5       2210275            1         1                     1
#
#            kickoff_time  minutes  provisional_start_time  started  \
# 0  2021-08-13T19:00:00Z       90                       0        1
# 1  2021-08-14T14:00:00Z       90                       0        1
# 2  2021-08-14T14:00:00Z       90                       0        1
# 3  2021-08-14T14:00:00Z       90                       0        1
# 4  2021-08-14T14:00:00Z       90                       0        1
#
#    away_team_id  away_team_score  home_team_id  home_team_score  \
# 0             1                0             3                2
# 1             4                2             5                1
# 2             7                0             6                3
# 3            16                1             8                3
# 4            20                0             9                1
#
#    home_team_difficulty  away_team_difficulty  pulse_id
# 0                     4                     2     66342
# 1                     2                     2     66343
# 2                     2                     4     66344
# 3                     2                     2     66345
# 4                     3                     3     66346

# %%
fixtures.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 380 entries, 0 to 379
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   fixture_id              380 non-null    int64
#  1   fixture_code            380 non-null    int64
#  2   gameweek_id             380 non-null    Int8
#  3   finished                380 non-null    int64
#  4   finished_provisional    380 non-null    int64
#  5   kickoff_time            380 non-null    object
#  6   minutes                 380 non-null    int64
#  7   provisional_start_time  380 non-null    int64
#  8   started                 380 non-null    Int8
#  9   away_team_id            380 non-null    int64
#  10  away_team_score         366 non-null    Int8
#  11  home_team_id            380 non-null    int64
#  12  home_team_score         366 non-null    Int8
#  13  home_team_difficulty    380 non-null    int64
#  14  away_team_difficulty    380 non-null    int64
#  15  pulse_id                380 non-null    int64
# dtypes: Int8(4), int64(11), object(1)
# memory usage: 38.7+ KB

# %% [markdown]
# ### Players

# %%
players = pd.read_sql_query("SELECT * FROM players", con)
print(players.shape)
players.head()
# Out:
# (736, 66)
#    player_id  player_code      first_name      second_name    web_name  \
# 0          1        80201           Bernd             Leno        Leno
# 1          2       115918      Rúnar Alex        Rúnarsson   Rúnarsson
# 2          3        47431         Willian  Borges Da Silva     Willian
# 3          4        54694  Pierre-Emerick       Aubameyang  Aubameyang
# 4          5        58822          Cédric           Soares      Cédric
#
#    team_id  team_code  chance_of_playing_next_round  \
# 0        1          3                         100.0
# 1        1          3                           0.0
# 2        1          3                           0.0
# 3        1          3                           0.0
# 4        1          3                         100.0
#
#    chance_of_playing_this_round  cost_change_event  ...  threat_rank  \
# 0                         100.0                  0  ...          598
# 1                           0.0                  0  ...          490
# 2                           0.0                  0  ...          732
# 3                           0.0                  0  ...           56
# 4                         100.0                  0  ...          319
#
#    threat_rank_type  ict_index_rank  ict_index_rank_type  \
# 0                60             442                   30
# 1                19             541                   55
# 2               306             732                  306
# 3                24             174                   31
# 4               104             261                   86
#
#    corners_and_indirect_freekicks_order  corners_and_indirect_freekicks_text  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   2.0
#
#    direct_freekicks_order  direct_freekicks_text  penalties_order  \
# 0                     NaN                                     NaN
# 1                     NaN                                     NaN
# 2                     NaN                                     NaN
# 3                     NaN                                     NaN
# 4                     3.0                                     NaN
#
#    penalties_text
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 66 columns]

# %%
players.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 66 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   player_id                             736 non-null    int64
#  1   player_code                           736 non-null    int64
#  2   first_name                            736 non-null    object
#  3   second_name                           736 non-null    object
#  4   web_name                              736 non-null    object
#  5   team_id                               736 non-null    int64
#  6   team_code                             736 non-null    int64
#  7   chance_of_playing_next_round          570 non-null    float64
#  8   chance_of_playing_this_round          569 non-null    float64
#  9   cost_change_event                     736 non-null    int64
#  10  cost_change_event_fall                736 non-null    int64
#  11  cost_change_start                     736 non-null    int64
#  12  cost_change_start_fall                736 non-null    int64
#  13  dreamteam_count                       736 non-null    int64
#  14  position_id                           736 non-null    int64
#  15  ep_next                               736 non-null    float64
#  16  ep_this                               736 non-null    float64
#  17  event_points                          736 non-null    int64
#  18  form                                  736 non-null    float64
#  19  in_dreamteam                          736 non-null    int64
#  20  news                                  736 non-null    object
#  21  news_added                            570 non-null    object
#  22  now_cost                              736 non-null    float64
#  23  points_per_game                       736 non-null    float64
#  24  selected_by_percent                   736 non-null    float64
#  25  special                               736 non-null    int64
#  26  squad_number                          0 non-null      object
#  27  status                                736 non-null    object
#  28  total_points                          736 non-null    int64
#  29  transfers_in                          736 non-null    int64
#  30  transfers_in_event                    736 non-null    int64
#  31  transfers_out                         736 non-null    int64
#  32  transfers_out_event                   736 non-null    int64
#  33  value_form                            736 non-null    float64
#  34  value_season                          736 non-null    float64
#  35  minutes                               736 non-null    int64
#  36  goals_scored                          736 non-null    int64
#  37  assists                               736 non-null    int64
#  38  clean_sheets                          736 non-null    int64
#  39  goals_conceded                        736 non-null    int64
#  40  own_goals                             736 non-null    int64
#  41  penalties_saved                       736 non-null    int64
#  42  penalties_missed                      736 non-null    int64
#  43  yellow_cards                          736 non-null    int64
#  44  red_cards                             736 non-null    int64
#  45  saves                                 736 non-null    int64
#  46  bonus                                 736 non-null    int64
#  47  bps                                   736 non-null    int64
#  48  influence                             736 non-null    float64
#  49  creativity                            736 non-null    float64
#  50  threat                                736 non-null    float64
#  51  ict_index                             736 non-null    float64
#  52  influence_rank                        736 non-null    int64
#  53  influence_rank_type                   736 non-null    int64
#  54  creativity_rank                       736 non-null    int64
#  55  creativity_rank_type                  736 non-null    int64
#  56  threat_rank                           736 non-null    int64
#  57  threat_rank_type                      736 non-null    int64
#  58  ict_index_rank                        736 non-null    int64
#  59  ict_index_rank_type                   736 non-null    int64
#  60  corners_and_indirect_freekicks_order  84 non-null     float64
#  61  corners_and_indirect_freekicks_text   736 non-null    object
#  62  direct_freekicks_order                83 non-null     float64
#  63  direct_freekicks_text                 736 non-null    object
#  64  penalties_order                       66 non-null     float64
#  65  penalties_text                        736 non-null    object
# dtypes: float64(17), int64(39), object(10)
# memory usage: 379.6+ KB

# %% [markdown]
# ### Positions

# %%
positions = pd.read_sql_query("SELECT * FROM positions", con)
print(positions.shape)
positions.head()
# Out:
# (4, 9)
#    position_id position_name_short position_name  squad_select  \
# 0            1                 GKP    Goalkeeper             2
# 1            2                 DEF      Defender             5
# 2            3                 MID    Midfielder             5
# 3            4                 FWD       Forward             3
#
#    squad_min_play  squad_max_play  ui_shirt_specific  sub_positions_locked  \
# 0               1               1                  1                  12.0
# 1               3               5                  0                   NaN
# 2               2               5                  0                   NaN
# 3               1               3                  0                   NaN
#
#    element_count
# 0             83
# 1            247
# 2            308
# 3             98

# %%
positions.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   position_id           4 non-null      int64
#  1   position_name_short   4 non-null      object
#  2   position_name         4 non-null      object
#  3   squad_select          4 non-null      int64
#  4   squad_min_play        4 non-null      int64
#  5   squad_max_play        4 non-null      int64
#  6   ui_shirt_specific     4 non-null      int64
#  7   sub_positions_locked  1 non-null      float64
#  8   element_count         4 non-null      int64
# dtypes: float64(1), int64(6), object(2)
# memory usage: 416.0+ bytes

# %% [markdown]
# ## Queries

# %% [markdown]
# ### Add team name and position to players data

# %% [markdown]
# #### SQLite

# %%
query = """
SELECT 
    pl.player_id,
    pl.first_name,
    pl.second_name,
    pl.team_id,
    t.team_name,
    pl.position_id,
    po.position_name
FROM players as pl 
INNER JOIN positions as po
    ON po.position_id = pl.position_id
INNER JOIN teams as t
    on t.team_id = pl.team_id
ORDER BY pl.player_id ASC;
"""

cursor.execute(query)
print(cursor.fetchall())
# Out:
# [(1, 'Bernd', 'Leno', 1, 'Arsenal', 1, 'Goalkeeper'), (2, 'Rúnar Alex', 'Rúnarsson', 1, 'Arsenal', 1, 'Goalkeeper'), (3, 'Willian', 'Borges Da Silva', 1, 'Arsenal', 3, 'Midfielder'), (4, 'Pierre-Emerick', 'Aubameyang', 1, 'Arsenal', 4, 'Forward'), (5, 'Cédric', 'Soares', 1, 'Arsenal', 2, 'Defender'), (6, 'Alexandre', 'Lacazette', 1, 'Arsenal', 4, 'Forward'), (7, 'Granit', 'Xhaka', 1, 'Arsenal', 3, 'Midfielder'), (8, 'Pablo', 'Marí', 1, 'Arsenal', 2, 'Defender'), (9, 'Héctor', 'Bellerín', 1, 'Arsenal', 2, 'Defender'), (10, 'Calum', 'Chambers', 2, 'Aston Villa', 2, 'Defender'), (11, 'Sead', 'Kolasinac', 1, 'Arsenal', 2, 'Defender'), (12, 'Mohamed Naser', 'El Sayed Elneny', 1, 'Arsenal', 3, 'Midfielder'), (13, 'Ainsley', 'Maitland-Niles', 1, 'Arsenal', 3, 'Midfielder'), (14, 'Rob', 'Holding', 1, 'Arsenal', 2, 'Defender'), (15, 'Thomas', 'Partey', 1, 'Arsenal', 3, 'Midfielder'), (16, 'Kieran', 'Tierney', 1, 'Arsenal', 2, 'Defender'), (17, 'Nicolas', 'Pépé', 1, 'Arsenal', 3, 'Midfielder'), (18, 'Lucas', 'Torreira', 1, 'Arsenal', 3, 'Midfielder'), (19, 'Joseph', 'Willock', 14, 'Newcastle', 3, 'Midfielder'), (20, 'Edward', 'Nketiah', 1, 'Arsenal', 4, 'Forward'), (21, 'Emile', 'Smith Rowe', 1, 'Arsenal', 3, 'Midfielder'), (22, 'Bukayo', 'Saka', 1, 'Arsenal', 3, 'Midfielder'), (23, 'Gabriel', 'Magalhães', 1, 'Arsenal', 2, 'Defender'), (24, 'Konstantinos', 'Mavropanos', 1, 'Arsenal', 2, 'Defender'), (25, 'Mattéo', 'Guendouzi', 1, 'Arsenal', 3, 'Midfielder'), (26, 'Gabriel Teodoro', 'Martinelli Silva', 1, 'Arsenal', 3, 'Midfielder'), (27, 'William', 'Saliba', 1, 'Arsenal', 2, 'Defender'), (28, 'Jed', 'Steer', 2, 'Aston Villa', 1, 'Goalkeeper'), (29, 'Conor', 'Hourihane', 2, 'Aston Villa', 3, 'Midfielder'), (30, 'Emiliano', 'Martínez', 2, 'Aston Villa', 1, 'Goalkeeper'), (31, 'Björn', 'Engels', 2, 'Aston Villa', 2, 'Defender'), (32, 'Bertrand', 'Traoré', 2, 'Aston Villa', 3, 'Midfielder'), (33, 'Jack', 'Grealish', 12, 'Man City', 3, 'Midfielder'), (34, 'Morgan', 'Sanson', 2, 'Aston Villa', 3, 'Midfielder'), (35, 'John', 'McGinn', 2, 'Aston Villa', 3, 'Midfielder'), (36, 'Kortney', 'Hause', 2, 'Aston Villa', 2, 'Defender'), (37, 'Mahmoud Ahmed', 'Ibrahim Hassan', 2, 'Aston Villa', 3, 'Midfielder'), (38, 'Tyrone', 'Mings', 2, 'Aston Villa', 2, 'Defender'), (39, 'Matt', 'Targett', 14, 'Newcastle', 2, 'Defender'), (40, 'Ollie', 'Watkins', 2, 'Aston Villa', 4, 'Forward'), (41, 'Marvelous', 'Nakamba', 2, 'Aston Villa', 3, 'Midfielder'), (42, 'Anwar', 'El Ghazi', 8, 'Everton', 3, 'Midfielder'), (43, 'Emiliano', 'Buendía Stati', 2, 'Aston Villa', 3, 'Midfielder'), (44, 'Matthew', 'Cash', 2, 'Aston Villa', 2, 'Defender'), (45, 'Ezri', 'Konsa Ngoyo', 2, 'Aston Villa', 2, 'Defender'), (46, 'Frédéric', 'Guilbert', 2, 'Aston Villa', 2, 'Defender'), (47, 'Wesley', 'Moraes', 2, 'Aston Villa', 4, 'Forward'), (48, 'Mbwana Ally', 'Samatta', 2, 'Aston Villa', 4, 'Forward'), (49, 'Keinan', 'Davis', 2, 'Aston Villa', 4, 'Forward'), (50, 'Douglas Luiz', 'Soares de Paulo', 2, 'Aston Villa', 3, 'Midfielder'), (51, 'Jacob', 'Ramsey', 2, 'Aston Villa', 3, 'Midfielder'), (52, 'Ashley', 'Young', 2, 'Aston Villa', 2, 'Defender'), (53, 'Adam', 'Lallana', 4, 'Brighton', 3, 'Midfielder'), (54, 'Jason', 'Steele', 4, 'Brighton', 1, 'Goalkeeper'), (55, 'Pascal', 'Groß', 4, 'Brighton', 3, 'Midfielder'), (56, 'Shane', 'Duffy', 4, 'Brighton', 2, 'Defender'), (57, 'Davy', 'Pröpper', 4, 'Brighton', 3, 'Midfielder'), (58, 'Dan', 'Burn', 14, 'Newcastle', 2, 'Defender'), (59, 'Lewis', 'Dunk', 4, 'Brighton', 2, 'Defender'), (60, 'Solomon', 'March', 4, 'Brighton', 3, 'Midfielder'), (61, 'Adam', 'Webster', 4, 'Brighton', 2, 'Defender'), (62, 'Joël', 'Veltman', 4, 'Brighton', 2, 'Defender'), (63, 'Neal', 'Maupay', 4, 'Brighton', 4, 'Forward'), (64, 'Leandro', 'Trossard', 4, 'Brighton', 3, 'Midfielder'), (65, 'Mathew', 'Ryan', 4, 'Brighton', 1, 'Goalkeeper'), (66, 'Alireza', 'Jahanbakhsh', 4, 'Brighton', 3, 'Midfielder'), (67, 'Ben', 'White', 1, 'Arsenal', 2, 'Defender'), (68, 'Bernard ...

# %%
# Storing the query results in a dataframe
query = """
SELECT 
    pl.player_id,
    pl.first_name,
    pl.second_name,
    pl.team_id,
    t.team_name,
    pl.position_id,
    po.position_name
FROM players as pl 
INNER JOIN positions as po
    ON po.position_id = pl.position_id
INNER JOIN teams as t
    on t.team_id = pl.team_id
ORDER BY pl.player_id ASC;
"""

pd.read_sql_query(query, con)
# Out:
#      player_id      first_name      second_name  team_id team_name  \
# 0            1           Bernd             Leno        1   Arsenal
# 1            2      Rúnar Alex        Rúnarsson        1   Arsenal
# 2            3         Willian  Borges Da Silva        1   Arsenal
# 3            4  Pierre-Emerick       Aubameyang        1   Arsenal
# 4            5          Cédric           Soares        1   Arsenal
# ..         ...             ...              ...      ...       ...
# 731        732           Tiago            Çukur       18   Watford
# 732        733          Adrian            Blake       18   Watford
# 733        734            Jack          Grieves       18   Watford
# 734        735          Joseph          McGlynn        5   Burnley
# 735        736         Anthony          Mancini        5   Burnley
#
#      position_id position_name
# 0              1    Goalkeeper
# 1              1    Goalkeeper
# 2              3    Midfielder
# 3              4       Forward
# 4              2      Defender
# ..           ...           ...
# 731            4       Forward
# 732            3    Midfielder
# 733            4       Forward
# 734            4       Forward
# 735            3    Midfielder
#
# [736 rows x 7 columns]

# %% [markdown]
# #### Pandas

# %%
(players[['player_id',
          'first_name',
          'second_name',
          'team_id',
          'position_id'
         ]]
 .assign(team_name = players.team_id.map(teams.set_index('team_id').team_name),
         position_name = players.position_id.map(positions.set_index('position_id').position_name)
        )
 .reindex(columns=['player_id',
                   'first_name',
                   'second_name',
                   'team_id',
                   'team_name',
                   'position_id',
                   'position_name'
                  ])
)
# Out:
#      player_id      first_name      second_name  team_id team_name  \
# 0            1           Bernd             Leno        1   Arsenal
# 1            2      Rúnar Alex        Rúnarsson        1   Arsenal
# 2            3         Willian  Borges Da Silva        1   Arsenal
# 3            4  Pierre-Emerick       Aubameyang        1   Arsenal
# 4            5          Cédric           Soares        1   Arsenal
# ..         ...             ...              ...      ...       ...
# 731        732           Tiago            Çukur       18   Watford
# 732        733          Adrian            Blake       18   Watford
# 733        734            Jack          Grieves       18   Watford
# 734        735          Joseph          McGlynn        5   Burnley
# 735        736         Anthony          Mancini        5   Burnley
#
#      position_id position_name
# 0              1    Goalkeeper
# 1              1    Goalkeeper
# 2              3    Midfielder
# 3              4       Forward
# 4              2      Defender
# ..           ...           ...
# 731            4       Forward
# 732            3    Midfielder
# 733            4       Forward
# 734            4       Forward
# 735            3    Midfielder
#
# [736 rows x 7 columns]

# %%
# Using pandasql
pysqldf = lambda q: sqldf(q, globals())
pysqldf("""
SELECT 
    pl.player_id,
    pl.first_name,
    pl.second_name,
    pl.team_id,
    t.team_name,
    pl.position_id,
    po.position_name
FROM players as pl 
INNER JOIN positions as po
    ON po.position_id = pl.position_id
INNER JOIN teams as t
    on t.team_id = pl.team_id
ORDER BY pl.player_id ASC;
"""
)
# Out:
#      player_id      first_name      second_name  team_id team_name  \
# 0            1           Bernd             Leno        1   Arsenal
# 1            2      Rúnar Alex        Rúnarsson        1   Arsenal
# 2            3         Willian  Borges Da Silva        1   Arsenal
# 3            4  Pierre-Emerick       Aubameyang        1   Arsenal
# 4            5          Cédric           Soares        1   Arsenal
# ..         ...             ...              ...      ...       ...
# 731        732           Tiago            Çukur       18   Watford
# 732        733          Adrian            Blake       18   Watford
# 733        734            Jack          Grieves       18   Watford
# 734        735          Joseph          McGlynn        5   Burnley
# 735        736         Anthony          Mancini        5   Burnley
#
#      position_id position_name
# 0              1    Goalkeeper
# 1              1    Goalkeeper
# 2              3    Midfielder
# 3              4       Forward
# 4              2      Defender
# ..           ...           ...
# 731            4       Forward
# 732            3    Midfielder
# 733            4       Forward
# 734            4       Forward
# 735            3    Midfielder
#
# [736 rows x 7 columns]

# %% [markdown]
# ### Count of fixtures per gameweek for each team

# %% [markdown]
# #### SQL

# %%
query = """
SELECT
    t2.gameweek_id,
    t2.team_id,
    t.team_name,
    COUNT(*) AS Fixtures
FROM
(
SELECT
    t1.gameweek_id,
    t1.team_id
FROM
(
    SELECT 
       f1.gameweek_id,
       f1.home_team_id AS team_id
    FROM fixtures as f1
    UNION ALL
    SELECT 
       f2.gameweek_id,
       f2.away_team_id AS team_id
    FROM fixtures as f2
) AS t1
) AS t2
INNER JOIN teams as t
    ON t.team_id = t2.team_id
WHERE t2.gameweek_id IS NOT NULL
GROUP BY 
    t2.gameweek_id,
    t2.team_id,
    t.team_name
ORDER BY 
    t2.gameweek_id ASC,
    t.team_name ASC
"""

cursor.execute(query)
print(cursor.fetchall())
# Out:
# [(1, 1, 'Arsenal', 1), (1, 2, 'Aston Villa', 1), (1, 3, 'Brentford', 1), (1, 4, 'Brighton', 1), (1, 5, 'Burnley', 1), (1, 6, 'Chelsea', 1), (1, 7, 'Crystal Palace', 1), (1, 8, 'Everton', 1), (1, 10, 'Leeds', 1), (1, 9, 'Leicester', 1), (1, 11, 'Liverpool', 1), (1, 12, 'Man City', 1), (1, 13, 'Man Utd', 1), (1, 14, 'Newcastle', 1), (1, 15, 'Norwich', 1), (1, 16, 'Southampton', 1), (1, 17, 'Spurs', 1), (1, 18, 'Watford', 1), (1, 19, 'West Ham', 1), (1, 20, 'Wolves', 1), (2, 1, 'Arsenal', 1), (2, 2, 'Aston Villa', 1), (2, 3, 'Brentford', 1), (2, 4, 'Brighton', 1), (2, 5, 'Burnley', 1), (2, 6, 'Chelsea', 1), (2, 7, 'Crystal Palace', 1), (2, 8, 'Everton', 1), (2, 10, 'Leeds', 1), (2, 9, 'Leicester', 1), (2, 11, 'Liverpool', 1), (2, 12, 'Man City', 1), (2, 13, 'Man Utd', 1), (2, 14, 'Newcastle', 1), (2, 15, 'Norwich', 1), (2, 16, 'Southampton', 1), (2, 17, 'Spurs', 1), (2, 18, 'Watford', 1), (2, 19, 'West Ham', 1), (2, 20, 'Wolves', 1), (3, 1, 'Arsenal', 1), (3, 2, 'Aston Villa', 1), (3, 3, 'Brentford', 1), (3, 4, 'Brighton', 1), (3, 5, 'Burnley', 1), (3, 6, 'Chelsea', 1), (3, 7, 'Crystal Palace', 1), (3, 8, 'Everton', 1), (3, 10, 'Leeds', 1), (3, 9, 'Leicester', 1), (3, 11, 'Liverpool', 1), (3, 12, 'Man City', 1), (3, 13, 'Man Utd', 1), (3, 14, 'Newcastle', 1), (3, 15, 'Norwich', 1), (3, 16, 'Southampton', 1), (3, 17, 'Spurs', 1), (3, 18, 'Watford', 1), (3, 19, 'West Ham', 1), (3, 20, 'Wolves', 1), (4, 1, 'Arsenal', 1), (4, 2, 'Aston Villa', 1), (4, 3, 'Brentford', 1), (4, 4, 'Brighton', 1), (4, 5, 'Burnley', 1), (4, 6, 'Chelsea', 1), (4, 7, 'Crystal Palace', 1), (4, 8, 'Everton', 1), (4, 10, 'Leeds', 1), (4, 9, 'Leicester', 1), (4, 11, 'Liverpool', 1), (4, 12, 'Man City', 1), (4, 13, 'Man Utd', 1), (4, 14, 'Newcastle', 1), (4, 15, 'Norwich', 1), (4, 16, 'Southampton', 1), (4, 17, 'Spurs', 1), (4, 18, 'Watford', 1), (4, 19, 'West Ham', 1), (4, 20, 'Wolves', 1), (5, 1, 'Arsenal', 1), (5, 2, 'Aston Villa', 1), (5, 3, 'Brentford', 1), (5, 4, 'Brighton', 1), (5, 5, 'Burnley', 1), (5, 6, 'Chelsea', 1), (5, 7, 'Crystal Palace', 1), (5, 8, 'Everton', 1), (5, 10, 'Leeds', 1), (5, 9, 'Leicester', 1), (5, 11, 'Liverpool', 1), (5, 12, 'Man City', 1), (5, 13, 'Man Utd', 1), (5, 14, 'Newcastle', 1), (5, 15, 'Norwich', 1), (5, 16, 'Southampton', 1), (5, 17, 'Spurs', 1), (5, 18, 'Watford', 1), (5, 19, 'West Ham', 1), (5, 20, 'Wolves', 1), (6, 1, 'Arsenal', 1), (6, 2, 'Aston Villa', 1), (6, 3, 'Brentford', 1), (6, 4, 'Brighton', 1), (6, 5, 'Burnley', 1), (6, 6, 'Chelsea', 1), (6, 7, 'Crystal Palace', 1), (6, 8, 'Everton', 1), (6, 10, 'Leeds', 1), (6, 9, 'Leicester', 1), (6, 11, 'Liverpool', 1), (6, 12, 'Man City', 1), (6, 13, 'Man Utd', 1), (6, 14, 'Newcastle', 1), (6, 15, 'Norwich', 1), (6, 16, 'Southampton', 1), (6, 17, 'Spurs', 1), (6, 18, 'Watford', 1), (6, 19, 'West Ham', 1), (6, 20, 'Wolves', 1), (7, 1, 'Arsenal', 1), (7, 2, 'Aston Villa', 1), (7, 3, 'Brentford', 1), (7, 4, 'Brighton', 1), (7, 5, 'Burnley', 1), (7, 6, 'Chelsea', 1), (7, 7, 'Crystal Palace', 1), (7, 8, 'Everton', 1), (7, 10, 'Leeds', 1), (7, 9, 'Leicester', 1), (7, 11, 'Liverpool', 1), (7, 12, 'Man City', 1), (7, 13, 'Man Utd', 1), (7, 14, 'Newcastle', 1), (7, 15, 'Norwich', 1), (7, 16, 'Southampton', 1), (7, 17, 'Spurs', 1), (7, 18, 'Watford', 1), (7, 19, 'West Ham', 1), (7, 20, 'Wolves', 1), (8, 1, 'Arsenal', 1), (8, 2, 'Aston Villa', 1), (8, 3, 'Brentford', 1), (8, 4, 'Brighton', 1), (8, 5, 'Burnley', 1), (8, 6, 'Chelsea', 1), (8, 7, 'Crystal Palace', 1), (8, 8, 'Everton', 1), (8, 10, 'Leeds', 1), (8, 9, 'Leicester', 1), (8, 11, 'Liverpool', 1), (8, 12, 'Man City', 1), (8, 13, 'Man Utd', 1), (8, 14, 'Newcastle', 1), (8, 15, 'Norwich', 1), (8, 16, 'Southampton', 1), (8, 17, 'Spurs', 1), (8, 18, 'Watford', 1), (8, 19, 'West Ham', 1), (8, 20, 'Wolves', 1), (9, 1, 'Arsenal', 1), (9, 2, 'Aston Villa', 1), (9, 3, 'Brentford', 1), (9, 4, 'Brighton', 1), (9, 5, 'Burnley', 1), (9, 6, 'Chelsea', 1), (9, 7, 'Crystal Palace', 1), (9, 8, 'Everton', 1), (9, 10, 'Leeds', 1), (9, 9, 'Leic ...

# %% [markdown]
# #### Pandas

# %%
(fixtures[['gameweek_id', 'home_team_id', 'away_team_id']]
 .append(fixtures.rename(columns={**dict(zip(['home_team_id'], ['away_team_id'])), **dict(zip(['away_team_id'], ['home_team_id']))}))
 .sort_index(ignore_index=True)
 .drop(columns=['away_team_id'])
 .rename(columns={'home_team_id': 'team_id'})
 .groupby(['gameweek_id', 'team_id']).size().to_frame('fixtures').reset_index()
 .assign(team_name = lambda x: x.team_id.map(teams.set_index('team_id').team_name))
 .astype({'gameweek_id': 'int8'})
 .reindex(columns=['gameweek_id',
                   'team_id',
                   'team_name',
                   'fixtures'
                  ])
)
# Out:
#      gameweek_id  team_id    team_name  fixtures
# 0              1        1      Arsenal         1
# 1              1        2  Aston Villa         1
# 2              1        3    Brentford         1
# 3              1        4     Brighton         1
# 4              1        5      Burnley         1
# ..           ...      ...          ...       ...
# 694           38       16  Southampton         1
# 695           38       17        Spurs         1
# 696           38       18      Watford         1
# 697           38       19     West Ham         1
# 698           38       20       Wolves         1
#
# [699 rows x 4 columns]

# %% [markdown]
# ### What teams have gameweeks with more than one fixture coming up?

# %%
current_gameweek = (gameweeks[gameweeks.finished == False]
                    .sort_values('gameweek_id', ascending=True)
                    .gameweek_id
                    .min()
                   )

# %%
(fixtures[['gameweek_id', 'home_team_id', 'away_team_id']]
 .append(fixtures.rename(columns={**dict(zip(['home_team_id'], ['away_team_id'])), **dict(zip(['away_team_id'], ['home_team_id']))}))
 .sort_index(ignore_index=True)
 .drop(columns=['away_team_id'])
 .rename(columns={'home_team_id': 'team_id'})
 .groupby(['gameweek_id', 'team_id']).size().to_frame('fixtures').reset_index()
 .assign(team_name = lambda x: x.team_id.map(teams.set_index('team_id').team_name))
 .astype({'gameweek_id': 'int8'})
 .reindex(columns=['gameweek_id',
                   'team_id',
                   'team_name',
                   'fixtures'
                  ])
 .query(f"gameweek_id >= {current_gameweek} and fixtures > 1")
)
# Out:
#      gameweek_id  team_id       team_name  fixtures
# 661           37        2     Aston Villa         2
# 664           37        5         Burnley         2
# 666           37        7  Crystal Palace         2
# 667           37        8         Everton         2
# 668           37        9       Leicester         2

# %% [markdown]
# ### Table of gameweek fixture counts for each team for the remaining fixtures

# %%
(fixtures[['gameweek_id', 'home_team_id', 'away_team_id']]
 .append(fixtures.rename(columns={**dict(zip(['home_team_id'], ['away_team_id'])), **dict(zip(['away_team_id'], ['home_team_id']))}))
 .sort_index(ignore_index=True)
 .drop(columns=['away_team_id'])
 .rename(columns={'home_team_id': 'team_id'})
 .groupby(['gameweek_id', 'team_id']).size().to_frame('fixtures').reset_index()
 .assign(team_name = lambda x: x.team_id.map(teams.set_index('team_id').team_name))
 .astype({'gameweek_id': 'int8'})
 .reindex(columns=['gameweek_id',
                   'team_id',
                   'team_name',
                   'fixtures'
                  ])
 .query(f"gameweek_id >= {current_gameweek}")
 .pivot_table(index=['team_id', 'team_name'], columns=['gameweek_id'], values='fixtures', fill_value=0)
)
# Out:
# gameweek_id             37  38
# team_id team_name
# 1       Arsenal          1   1
# 2       Aston Villa      2   1
# 3       Brentford        1   1
# 4       Brighton         1   1
# 5       Burnley          2   1
# 6       Chelsea          1   1
# 7       Crystal Palace   2   1
# 8       Everton          2   1
# 9       Leicester        2   1
# 10      Leeds            1   1
# 11      Liverpool        1   1
# 12      Man City         1   1
# 13      Man Utd          0   1
# 14      Newcastle        1   1
# 15      Norwich          1   1
# 16      Southampton      1   1
# 17      Spurs            1   1
# 18      Watford          1   1
# 19      West Ham         1   1
# 20      Wolves           1   1

# %% [markdown]
# ### Table of remaining fixtures

# %%
# Setting this as a constant as the code below to derive the table of remaining fixtures is not dynamic in its current form
CURRENT_GAMEWEEK = 36

# %%
# Colour home and away matches
def colour(team):
    if team.isupper():
        colour = 'green'
    elif team.islower():
        colour = 'red'
    else:
        colour = 'white'
    return 'background-color: %s' % colour

# %%
(
    fixtures[['fixture_id', 'kickoff_time', 'gameweek_id', 'home_team_id', 'away_team_id']]
    .append(fixtures.rename(columns={**dict(zip(['home_team_id'], ['away_team_id'])),
                                     **dict(zip(['away_team_id'], ['home_team_id']))
                                    }))
    .sort_index(ignore_index=True)
    .drop(columns=['away_team_id'])
    .rename(columns={'home_team_id': 'team_id'})
    .assign(team_name = lambda x: x.team_id.map(teams.set_index('team_id').team_name),
            team_short_name = lambda x: x.team_id.map(teams.set_index('team_id').team_short_name),
            gameweek_name = lambda x: x.gameweek_id.map(gameweeks.set_index('gameweek_id').gameweek_name)
           )
    .query(f"gameweek_id >= {CURRENT_GAMEWEEK}")
    .merge(fixtures[['fixture_id', 'home_team_id']], how='left',
           left_on=['fixture_id', 'team_id'],
           right_on=['fixture_id', 'home_team_id']
          )
    .astype({'gameweek_id': 'int8',
             'home_team_id': 'Int8'
            })
    .assign(home = lambda x: np.where(x.home_team_id.isnull(), 0, 1),
            venue = lambda x: np.where(x.home == 1, 'home', 'away'),
            fixture_dummy_id = lambda x: np.where(x.venue == 'home', x.fixture_id, -1*x.fixture_id)
           )
    .sort_values(['gameweek_id', 'kickoff_time'])
    .assign(gameweek_fixture_number = lambda x: x.groupby(['gameweek_id', 'team_id']).cumcount()+1,
            gameweek_fixture_name = lambda x: np.where(x.gameweek_fixture_number == 1, 'Fixture One', 'Fixture Two')
           )
    .reindex(columns=['fixture_dummy_id',
                      'gameweek_name',
                      'team_id',
                      'gameweek_fixture_name'
                     ])
    .pivot(index=['team_id'], columns=['gameweek_name', 'gameweek_fixture_name'], values='fixture_dummy_id').sort_index(axis='columns', level='gameweek_name')
    .fillna(0)
    .astype('Int16')
    .pipe(lambda x: x.set_axis([' '.join(col) for col in x.columns.values], axis=1))
    .reset_index()
    .assign(team_name = lambda x: x.team_id.map(teams.set_index('team_id').team_short_name),
            Gameweek_36_Fixture_One_Team = lambda x: np.where(x['Gameweek 36 Fixture One'] < 0,
                                                              (-1*x['Gameweek 36 Fixture One']).map(fixtures.set_index('fixture_id').home_team_id),
                                                              x['Gameweek 36 Fixture One'].map(fixtures.set_index('fixture_id').away_team_id)
                                                             ).astype('int8'),
            Gameweek_36_Fixture_One_Opponent = lambda x: np.where(x['Gameweek 36 Fixture One'] < 0,
                                                                  x['Gameweek_36_Fixture_One_Team'].map(teams.set_index('team_id').team_short_name).str.lower(),
                                                                  x['Gameweek_36_Fixture_One_Team'].map(teams.set_index('team_id').team_short_name).str.upper()
                                                                 ),
            Gameweek_36_Fixture_Two_Team = lambda x: np.where(x['Gameweek 36 Fixture Two'] < 0,
                                                              (-1*x['Gameweek 36 Fixture Two']).map(fixtures.set_index('fixture_id').home_team_id),
                                                              x['Gameweek 36 Fixture Two'].map(fixtures.set_index('fixture_id').away_team_id)
                                                             ).astype('int8'),
            Gameweek_36_Fixture_Two_Opponent = lambda x: np.where(x['Gameweek 36 Fixture Two'] < 0,
                                                                  x['Gameweek_36_Fixture_Two_Team'].map(teams.set_index('team_id').team_short_name).str.lower(),
                                                                  x['Gameweek_36_Fixture_Two_Team'].map(teams.set_index('team_id').team_short_name).str.upper()
                                                                 ),
            Gameweek_37_Fixture_One_Team = lambda x: np.where(x['Gameweek 37 Fixture One'] < 0,
                                                              (-1*x['Gameweek 37 Fixture One']).map(fixtures.set_index('fixture_id').home_team_id),
                                                              x['Gameweek 37 Fixture One'].map(fixtures.set_index('fixture_id').away_team_id)
                                                             ).astype('int8'),
            Gameweek_37_Fixture_One_Opponent = lambda x: np.where(x['Gameweek 37 Fixture One'] < 0,
                                                                  x['Gameweek_37_Fixture_One_Team'].map(teams.set_index('team_id').team_short_name).str.lower(),
                                                                  x['Gameweek_37_Fixture_One_Team'].map(teams.set_index('team_id').team_short_name).str.upper()
                                                                 ),
            Gameweek_37_Fixture_Two_Team = lambda x: np.where(x['Gameweek 37 Fixture Two'] < 0,
                                                              (-1*x['Gameweek 37 Fixture Two']).map(fixtures.set_index('fixture_id').home_team_id),
                                                              x['Gameweek 37 Fixture Two'].map(fixtures.set_index('fixture_id').away_team_id)
                                                             ).astype('int8'),
            Gameweek_37_Fixture_Two_Opponent = lambda x: np.where(x['Gameweek 37 Fixture Two'] < 0,
                                                                  x['Gameweek_37_Fixture_Two_Team'].map(teams.set_index('team_id').team_short_name).str.lower(),
                                                                  x['Gameweek_37_Fixture_Two_Team'].map(teams.set_index('team_id').team_short_name).str.upper()
                                                                 ),
            Gameweek_38_Fixture_One_Team = lambda x: np.where(x['Gameweek 38 Fixture One'] < 0,
                                                              (-1*x['Gameweek 38 Fixture One']).map(fixtures.set_index('fixture_id').home_team_id),
                                                              x['Gameweek 38 Fixture One'].map(fixtures.set_index('fixture_id').away_team_id)
                                                             ).astype('int8'),
            Gameweek_38_Fixture_One_Opponent = lambda x: np.where(x['Gameweek 38 Fixture One'] < 0,
                                                                  x['Gameweek_38_Fixture_One_Team'].map(teams.set_index('team_id').team_short_name).str.lower(),
                                                                  x['Gameweek_38_Fixture_One_Team'].map(teams.set_index('team_id').team_short_name).str.upper()
                                                                 ) 
           )
    .drop(columns=['team_id',
                   'Gameweek 36 Fixture One',
                   'Gameweek_36_Fixture_One_Team',
                   'Gameweek 36 Fixture Two',
                   'Gameweek_36_Fixture_Two_Team',
                   'Gameweek 37 Fixture One',
                   'Gameweek_37_Fixture_One_Team',
                   'Gameweek 37 Fixture Two',
                   'Gameweek_37_Fixture_Two_Team',
                   'Gameweek 38 Fixture One',
                   'Gameweek_38_Fixture_One_Team'
                  ])
    .fillna('')
    .pipe(lambda x: x.set_axis(x.columns.str.replace('_',' '), axis=1))
    .pipe(lambda x: x.style.applymap(colour, subset=x.iloc[:, 1:7].columns))
)
# Out:
# <style type="text/css">
# #T_0053b_row0_col1, #T_0053b_row0_col5, #T_0053b_row1_col2, #T_0053b_row1_col3, #T_0053b_row1_col4, #T_0053b_row2_col1, #T_0053b_row2_col5, #T_0053b_row3_col1, #T_0053b_row3_col5, #T_0053b_row4_col1, #T_0053b_row4_col5, #T_0053b_row5_col1, #T_0053b_row5_col3, #T_0053b_row5_col5, #T_0053b_row6_col1, #T_0053b_row6_col5, #T_0053b_row7_col3, #T_0053b_row7_col4, #T_0053b_row8_col1, #T_0053b_row8_col2, #T_0053b_row8_col5, #T_0053b_row9_col2, #T_0053b_row9_col3, #T_0053b_row10_col1, #T_0053b_row10_col5, #T_0053b_row11_col1, #T_0053b_row11_col5, #T_0053b_row13_col3, #T_0053b_row14_col1, #T_0053b_row14_col5, #T_0053b_row15_col3, #T_0053b_row16_col2, #T_0053b_row16_col3, #T_0053b_row17_col2, #T_0053b_row17_col3, #T_0053b_row18_col3, #T_0053b_row19_col2, #T_0053b_row19_col3 {
#   background-color: green;
# }
# #T_0053b_row0_col2, #T_0053b_row0_col3, #T_0053b_row1_col1, #T_0053b_row1_col5, #T_0053b_row2_col3, #T_0053b_row3_col3, #T_0053b_row4_col3, #T_0053b_row4_col4, #T_0053b_row5_col2, #T_0053b_row6_col3, #T_0053b_row6_col4, #T_0053b_row7_col1, #T_0053b_row7_col2, #T_0053b_row7_col5, #T_0053b_row8_col3, #T_0053b_row8_col4, #T_0053b_row9_col1, #T_0053b_row9_col5, #T_0053b_row10_col2, #T_0053b_row10_col3, #T_0053b_row11_col2, #T_0053b_row11_col3, #T_0053b_row12_col1, #T_0053b_row12_col5, #T_0053b_row13_col1, #T_0053b_row13_col5, #T_0053b_row14_col2, #T_0053b_row14_col3, #T_0053b_row15_col1, #T_0053b_row15_col5, #T_0053b_row16_col1, #T_0053b_row16_col5, #T_0053b_row17_col1, #T_0053b_row17_col5, #T_0053b_row18_col1, #T_0053b_row18_col5, #T_0053b_row19_col1, #T_0053b_row19_col5 {
#   background-color: red;
# }
# #T_0053b_row0_col4, #T_0053b_row2_col2, #T_0053b_row2_col4, #T_0053b_row3_col2, #T_0053b_row3_col4, #T_0053b_row4_col2, #T_0053b_row5_col4, #T_0053b_row6_col2, #T_0053b_row9_col4, #T_0053b_row10_col4, #T_0053b_row11_col4, #T_0053b_row12_col2, #T_0053b_row12_col3, #T_0053b_row12_col4, #T_0053b_row13_col2, #T_0053b_row13_col4, #T_0053b_row14_col4, #T_0053b_row15_col2, #T_0053b_row15_col4, #T_0053b_row16_col4, #T_0053b_row17_col4, #T_0053b_row18_col2, #T_0053b_row18_col4, #T_0053b_row19_col4 {
#   background-color: white;
# }
# </style>
# <table id="T_0053b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >team name</th>
#       <th class="col_heading level0 col1" >Gameweek 36 Fixture One Opponent</th>
#       <th class="col_heading level0 col2" >Gameweek 36 Fixture Two Opponent</th>
#       <th class="col_heading level0 col3" >Gameweek 37 Fixture One Opponent</th>
#       <th class="col_heading level0 col4" >Gameweek 37 Fixture Two Opponent</th>
#       <th class="col_heading level0 col5" >Gameweek 38 Fixture One Opponent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0053b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0053b_row0_col0" class="data row0 col0" >ARS</td>
#       <td id="T_0053b_row0_col1" class="data row0 col1" >LEE</td>
#       <td id="T_0053b_row0_col2" class="data row0 col2" >tot</td>
#       <td id="T_0053b_row0_col3" class="data row0 col3" >new</td>
#       <td id="T_0053b_row0_col4" class="data row0 col4" ></td>
#       <td id="T_0053b_row0_col5" class="data row0 col5" >EVE</td>
#     </tr>
#     <tr>
#       <th id="T_0053b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0053b_row1_col0" class="data row1 col0" >AVL</td>
#       <td id="T_0053b_row1_col1" class="data row1 col1" >bur</td>
#       <td id="T_0053b_row1_col2" class="data row1 col2" >LIV</td>
#       <td id="T_0053b_row1_col3" class="data row1 col3" >CRY</td>
#       <td id="T_0053b_row1_col4" class="data row1 col4" >BUR</td>
#       <td id="T_0053b_row1_col5" class="data row1 col5" >mci</td>
#     </tr>
#     <tr>
#       <th id="T_0053b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0053b_row2_col0" class="data row2 col0" >BRE</td>
#       <td id="T_0053b_row2_col1" class="data row2 col1" >SOU</td>
#       <td id="T_0053b_row2_col2" class="data row2 col2" ></td>
#       <td id="T_0053b_row2_col3" class="data row2 col3" >eve</td>
#       <td id="T_0053b_row2_col4" class="data row2 col4" ></td>
#       <td id="T_0053b_row2_col5" class="data row2 col5" >LEE</td>
#     </tr>
#     <tr>
#       <th id="T_0053b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0053b_row3_col0" class="data row3 col0" >BHA</td>
#       <td id="T_0053b_row3_col1" class="data row3 col1" >MUN</td>
#       <td id="T_0053b_row3_col2" class="data row3 col2" ></td>
#       <td id="T_0053b_row3_col3" class="data row3 col3" >lee</td>
#       <td id="T_0053b_row3_col4" class="data row3 col4" ></td>
#       <td id="T_0053b_row3_col5" class="data row3 col5" >WHU</td>
#     </tr>
#     <tr>
#       <th id="T_0053b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0053b_row4_col0" class="data row4 col0" >BUR</td>
#       <td id="T_0053b_row4_col1" class="data row4 col1" >AVL</td>
#       <td id="T_0053b_row4_col2" class="data row4 col2" ></td>
#       <td id="T_0053b_row4_col3" class="data row4 col3" >tot</td>
#       <td id="T_0053b_row4_col4" class="data row4 col4" >avl</td>
#       <td id="T_0053b_row4_col5" class="data row4 col5" >NEW</td>
#     </tr>
#     <tr>
#       <th id="T_0053b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0053b_row5_col0" class="data row5 col0" >CHE</td>
#       <td id="T_0053b_row5_col1" class="data row5 col1" >WOL</td>
#       <td id="T_0053b_row5_col2" class="data row5 col2" >lee</td>
#       <td id="T_0053b_row5_col3" class="data row5 col3" >LEI</td>
#       <td id="T_0053b_row5_col4" class="data row5 col4" ></td>
#       <td id="T_0053b_row5_col5" class="data row5 col5" >WAT</td>
#     </tr>
#     <tr>
#       <th id="T_0053b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0053b_row6_col0" class="data row6 col0" >CRY</td>
#       <td id="T_0053b_row6_col1" class="data row6 col1" >WAT</td>
#       <td id="T_0053b_row6_col2" class="data row6 col2" ></td>
#       <td id="T_0053b_row6_col3" class="data row6 col3" >avl</td>
#       <td id="T_0053b_row6_col4" class="data row6 col4" >eve</td>
#       <td id="T_0053b_row6_col5" class="data row6 col5" >MUN</td>
#     </tr>
#     <tr>
#       <th id="T_0053b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0053b_row7_col0" class="data row7 col0" >EVE</td>
#       <td id="T_0053b_row7_col1" class="data row7 col1" >lei</td>
#       <td id="T_0053b_row7_col2" class="data row7 col2" >wat</td>
#       <td id="T_0053b_row7_col3" class="data row7 col3" >BRE</td>
#       <td id="T_0053b_row7_col4" class="data row7 col4" >CRY</td>
#       <td id="T_0053b_row7_col5" class="data row7 col5" >ars</td>
#     </tr>
#     <tr>
#       <th id="T_0053b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0053b_row8_col0" class="data row8 col0" >LEI</td>
#       <td id="T_0053b_row8_col1" class="data row8 col1" >EVE</td>
#       <td id="T_0053b_row8_col2" class="data row8 col2" >NOR</td>
#       <td id="T_0053b_row8_col3" class="data row8 col3" >wat</td>
#       <td id="T_0053b_row8_col4" class="data row8 col4" >che</td>
#       <td id="T_0053b_row8_col5" class="data row8 col5" >SOU</td>
#     </tr>
#     <tr>
#       <th id="T_0053b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0053b_row9_col0" class="data row9 col0" >LEE</td>
#       <td id="T_0053b_row9_col1" class="data row9 col1" >ars</td>
#       <td id="T_0053b_row9_col2" class="data row9 col2" >CHE</td>
#       <td id="T_0053b_row9_col3" class="data row9 col3" >BHA</td>
#       <td id="T_0053b_row9_col4" class="data row9 col4" ></td>
#       <td id="T_0053b_row9_col5" class="data row9 col5" >bre</td>
#     </tr>
#     <tr>
#       <th id="T_0053b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0053b_row10_col0" class="data row10 col0" >LIV</td>
#       <td id="T_0053b_row10_col1" class="data row10 col1" >TOT</td>
#       <td id="T_0053b_row10_col2" class="data row10 col2" >avl</td>
#       <td id="T_0053b_row10_col3" class="data row10 col3" >sou</td>
#       <td id="T_00

# %% [markdown]
# ### Close connection to the database

# %%
con.close()

# %% [markdown]
# ## Summary
# We have explored some simple queries of the fpl database and compared SQL and pandas query equivalents.
#
# Further queries may be added in the future.
